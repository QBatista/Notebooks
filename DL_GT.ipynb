# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import quantecon
import quantecon.game_theory as gt

g_PD = gt.NormalFormGame((2, 2))
g_PD[0, 0] = 1, 1
g_PD[0, 1] = -2, 3
g_PD[1, 0] = 3, -2
g_PD[1, 1] = 0, 0

g_BoS = gt.NormalFormGame((2, 2))
g_BoS[0, 0] = 4, 3
g_BoS[0, 1] = 0, 0
g_BoS[1, 0] = 0, 0
g_BoS[1, 1] = 3, 4

g_MP = gt.NormalFormGame((2, 2))
g_MP[0, 0] = -2, 2
g_MP[0, 1] = 2, -2
g_MP[1, 0] = 2, -2
g_MP[1, 1] = -2, 2

# %%
gt.support_enumeration(g_PD)
# Out:
# [(array([ 0.,  1.]), array([ 0.,  1.]))]

# %%
gt.support_enumeration(g_BoS)
# Out:
# [(array([ 1.,  0.]), array([ 1.,  0.])),
#  (array([ 0.,  1.]), array([ 0.,  1.])),
#  (array([ 0.66666667,  0.33333333]), array([ 0.33333333,  0.66666667]))]

# %%
gt.support_enumeration(g_MP)
# Out:
# [(array([ 0.5,  0.5]), array([ 0.5,  0.5]))]

# %%
from scipy.stats import rv_discrete

def create_network_graph(action_space, optimizer):
    weights = tf.Variable(tf.ones([action_space]))
    chosen_action = tf.argmax(weights, 0)

    reward_holder = tf.placeholder(shape=[1], dtype=tf.float32)
    action_holder = tf.placeholder(shape=[1], dtype=tf.int32)
    responsible_weight = tf.slice(weights, action_holder, [1])
    loss = -(tf.log(responsible_weight)*reward_holder)
    update = optimizer.minimize(loss)
    
    sess = tf.Session()
    
    return weights, chosen_action, reward_holder, action_holder, responsible_weight, loss, update, sess


def play_action(game, player, p1_action, p2_action):
    '''Plays the game once an action has been decided by player 2'''
    return game.payoff_profile_array[p1_action][p2_action][player]


def choose_opponent_action(action_space, density):
    distribution = rv_discrete(values=(action_space, density))
    return distribution.rvs()


def choose_action(ra_prob, action_space, sess, chosen_action):
    '''Choose either a random action or one from our network.'''
    if np.random.rand() < ra_prob:
        return np.random.randint(action_space)
    else: 
        return sess.run(chosen_action)


def play_game_nvh(game, opponent_actions, opponent_density, episodes=5000, ra_prob=0.1):
    '''Plays game between a network and a rational agent.'''
    # Graph
    tf.reset_default_graph()
    
    action_history = []
    opponent_action_history = []

    action_space = game.nums_actions[0]
    
    weights = tf.Variable(tf.ones([action_space]))
    chosen_action = tf.argmax(weights, 0)

    reward_holder = tf.placeholder(shape=[1], dtype=tf.float32)
    action_holder = tf.placeholder(shape=[1], dtype=tf.int32)
    responsible_weight = tf.slice(weights, action_holder, [1])
    loss = -(tf.log(responsible_weight)*reward_holder)
    optimizer = tf.train.AdamOptimizer(learning_rate=0.001)
    update = optimizer.minimize(loss)

    total_reward = np.zeros(action_space)
    
    init = tf.global_variables_initializer()

    # Launch the tensorflow graph
    with tf.Session() as sess:
        sess.run(init)
        for i in range(episodes):
            if i<100:
                action = choose_action(0.5, action_space, sess, chosen_action)
            else:
                action = choose_action(ra_prob, action_space, sess, chosen_action)
            opponent_action = choose_opponent_action(opponent_actions, opponent_density)
            reward = play_action(game, 0, action, opponent_action)
            action_history.append(action)
            opponent_action_history.append(opponent_action)
            
            
            # Update the network.
            _, resp, ww = sess.run([update, responsible_weight, weights],
                                    feed_dict={reward_holder:[reward],
                                               action_holder:[action]})

            #Update our running tally of scores.
            total_reward[action] += reward
#             if i % 50 == 0:
#                 print("iteration " + str(i) + ": " + str(total_reward))

    print("The network thinks action " + str(np.argmax(ww)) + " is the most promising....")
    print(ww)
    print(sum(opponent_action_history)/len(opponent_action_history))
    print(total_reward)
    return np.argmax(ww) 


def play_game_nvn(game, episodes=10000, ra_prob=0.1):
    '''Plays game between a network and a rational agent.'''
    # Graph
    tf.reset_default_graph()
    
    action_history_1 = []
    action_history_2 = []
    
    action_space = game.nums_actions[0]
    
    w1, ca1, rh1, ah1, rw1, l1, update1, sess1 = create_network_graph(action_space, tf.train.AdamOptimizer(learning_rate=0.001))
    w2, ca2, rh2, ah2, rw2, l2, update2, sess2 = create_network_graph(action_space, tf.train.GradientDescentOptimizer(learning_rate=0.001))

    init = tf.global_variables_initializer()

    sess1.run(init)
    sess2.run(init)

    for i in range(episodes):
        if i < 100:
            action_1 = choose_action(0.5, action_space, sess1, ca1)
            action_2 = choose_action(0.5, action_space, sess2, ca2)
        else:
            action_1 = choose_action(ra_prob, action_space, sess1, ca1)
            action_2 = choose_action(ra_prob, action_space, sess2, ca2)
        reward_1 = play_action(game, 0, action_1, action_2)
        reward_2 = play_action(game, 1, action_1, action_2)
        action_history_1.append(action_1)
        action_history_2.append(action_2)
        

        #Update the network.
        _, resp, ww_1 = sess1.run([update1, rw1, w1],
                                   feed_dict={rh1:[reward_1], ah1:[action_1]})

        _, resp, ww_2 = sess2.run([update2, rw2, w2],
                                   feed_dict={rh2:[reward_2], ah2:[action_2]})

    print("Network 1 thinks action " + str(np.argmax(ww_1)) + " is the most promising.")
    print("Network 2 thinks action " + str(np.argmax(ww_2)) + " is the most promising.")
    print(ww_1)
    print(ww_2)
    return np.argmax(ww_1), np.argmax(ww_2)

# %%
hist1 = []
hist2 = []
for i in range(100):
    hist_1, hist_2 = play_game_nvn(g_MP)
    hist1.append(hist_1)
    hist2.append(hist_2)
# Out:
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.69037926  0.85152113]
# [ 0.94905168  1.21218181]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.96749449  1.16198349]
# [ 1.8125397   0.87017637]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.83708203  1.46665204]
# [ 1.01246333  1.48879623]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.33685601  0.94636571]
# [ 0.92579228  1.6545155 ]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.89412832  1.66279244]
# [ 0.97022438  1.22498798]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.67191362  0.8723098 ]
# [ 1.25744915  0.93707401]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.41412258  0.9424926 ]
# [ 1.56773269  0.86366916]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.53707981  0.88283157]
# [ 1.44120872  0.91093373]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.92052829  0.97605568]
# [ 0.84652758  1.9730078 ]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.77255726  0.94888377]
# [ 0.870565    1.15185285]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.36094391  0.92604059]
# [ 1.64223289  0.89068598]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.1760838   0.98147959]
# [ 1.70918477  0.95580369]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.01476932  0.87675399]
# [ 0.87013048  1.93420744]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.2234925  0.879529 ]
# [ 1.75660121  0.84731895]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.95905119  1.45657539]
# [ 1.59693122  0.79361606]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.78552604  0.87537545]
# [ 1.10326421  0.90009242]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.80726314  0.85172904]
# [ 0.92998803  1.08905435]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.86421919  1.66810811]
# [ 1.32885146  0.89730233]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.85816628  1.50397062]
# [ 0.98044938  1.43963778]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.93271214  1.56791198]
# [ 0.96859699  1.30903506]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.57904053  0.92251569]
# [ 0.95540702  1.34219539]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.8933022   1.44944406]
# [ 0.92824936  1.49307382]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.51500595  0.8484832 ]
# [ 1.43394899  1.00442791]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.59166932  0.91731524]
# [ 1.34798408  0.98061931]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.94988966  1.08762908]
# [ 0.93437535  1.79361856]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.92403972  1.73947322]
# [ 0.99512172  0.96180379]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.00746477  1.00170898]
# [ 1.88733947  0.80123758]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.80290246  0.8341521 ]
# [ 1.08471406  0.96835417]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.91562051  1.25784242]
# [ 1.73691189  0.91260016]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.85819066  1.73892927]
# [ 1.05335045  1.02187884]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.86886376  1.16421366]
# [ 0.96383899  1.78460491]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.9078083   1.15475988]
# [ 1.8003149   0.95123917]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.89605212  1.75071299]
# [ 0.89771104  1.18538117]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.95605212  0.89178526]
# [ 1.00426221  1.9038353 ]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.93886781  1.16171718]
# [ 0.83539736  1.80488968]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.51102054  0.97396088]
# [ 1.41196835  0.92208052]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.94472349  1.40538085]
# [ 1.61263788  0.91665792]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.68463421  0.9326663 ]
# [ 1.26064789  0.88868982]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.87535518  1.85143781]
# [ 1.02879333  0.86327708]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.55371535  0.92925084]
# [ 0.97205681  1.36584616]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.0576092   0.97336149]
# [ 1.81250966  0.9365977 ]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.74993241  0.84478635]
# [ 1.01403749  1.10519528]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.96194339  1.63217545]
# [ 1.24973595  0.9472093 ]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.86075622  1.80537224]
# [ 1.01868701  0.94901395]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.87020189  1.77224565]
# [ 1.01669466  0.98413819]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.58122373  0.84594917]
# [ 1.361359    0.96647912]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.26912963  0.91801   ]
# [ 1.68193662  0.92800015]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.52428973  0.874538  ]
# [ 1.00610399  1.41027558]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.36732841  0.86336941]
# [ 0.97414774  1.64354753]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.0425272   0.88734013]
# [ 0.89725524  1.90293527]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.81169659  1.76474392]
# [ 1.1051445   0.98603046]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.90599769  1.28759658]
# [ 0.92807919  1.66525865]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.67515302  0.84216249]
# [ 0.99808139  1.26374316]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.5389719   0.89219934]
# [ 0.98601145  1.41591227]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.77463198  0.85469019]
# [ 1.08287227  0.97045588]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.63302064  0.84314936]
# [ 1.03548789  1.22029364]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.37433517  0.95544338]
# [ 1.57646775  0.91518229]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.92800975  1.21560085]
# [ 0.91270137  1.72766471]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.62208843  0.9072994 ]
# [ 0.92340928  1.34061635]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.93452001  1.46392953]
# [ 1.45785677  0.94490629]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.60494554  0.82801485]
# [ 0.97165799  1.36560965]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.95831525  1.49644423]
# [ 0.87495619  1.49034345]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.86275929  1.81234097]
# [ 0.95806336  1.02208304]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.32471299  0.86284238]
# [ 1.68796349  0.86347008]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.8699407   1.32180977]
# [ 0.97025222  1.63619506]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.73547053  0.9407571 ]
# [ 0.96398056  1.12879193]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.54738188  0.98341501]
# [ 1.40775347  0.85214287]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.96179456  1.44394326]
# [ 0.89075005  1.52091897]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.33960414  0.93564332]
# [ 0.91275728  1.70454955]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.07492149  0.91531509]
# [ 0.93660438  1.83009255]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.21558332  0.94065803]
# [ 1.78355885  0.87468427]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.86672294  1.21837628]
# [ 1.75289941  1.01217306]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.9529863   1.04537392]
# [ 1.85183096  0.88840687]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.89508033  1.69206977]
# [ 1.28917742  0.89732361]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.43440139  0.83148319]
# [ 0.95725197  1.57631934]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.88062882  1.12708831]
# [ 0.94901228  1.81895411]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.93085104  1.0148598 ]
# [ 1.90509105  0.86099946]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.87146586  1.72572446]
# [ 0.91743201  1.19698834]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.74809754  0.90443146]
# [ 1.04927576  0.97478908]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.90637243  1.45043921]
# [ 1.57899928  0.91474384]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.94114947  0.97829711]
# [ 0.87923366  1.93210959]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.78253943  1.60299516]
# [ 1.06627917  1.258623  ]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.88992739  1.82387519]
# [ 1.01863492  0.97389573]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.90546864  1.2366159 ]
# [ 1.79360604  0.88141   ]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.90826416  1.77911484]
# [ 1.07047343  0.93850911]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.91312015  1.54003799]
# [ 1.48767555  0.91474521]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.96991569  1.20374596]
# [ 0.90202343  1.72439063]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.42971611  0.89442647]
# [ 1.52995741  0.94073886]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.79276907  1.76408172]
# [ 0.98473728  1.09568024]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.59137726  0.8666662 ]
# [ 0.94506711  1.40489697]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.69024742  0.9011336 ]
# [ 0.9277578   1.22865009]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.96819472  1.07122958]
# [ 0.88577336  1.85058272]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.13970387  0.95853692]
# [ 1.72773623  0.99261409]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.98478991  1.08214927]
# [ 1.9010371   0.74150455]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 0.92076486  1.05665839]
# [ 1.83100367  1.01612651]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.89480293  1.51898086]
# [ 0.97031254  1.4074223 ]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.64508498  0.91051704]
# [ 0.97804034  1.27645516]
# Network 1 thinks action 1 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 0.97106916  1.45319462]
# [ 0.87979496  1.51973152]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 1 is the most promising.
# [ 1.23072326  0.9799484 ]
# [ 0.83515573  1.75320458]
# Network 1 thinks action 0 is the most promising.
# Network 2 thinks action 0 is the most promising.
# [ 1.68864822  0.8940863 ]
# [ 1.19361091  0.96830642]

# %%
cnt = 0
for i in range(len(hist1)):
    if hist1[i] == hist2[i]:
        cnt += 1
print(cnt)
# Out:
# 50

# %%
hist1 != hist2
# Out:
# True

# %%
sum(hist1)
# Out:
# 10

# %%
hist = []
for i in range(100):
    hist.append(play_game_nvh(g_MP, [0, 1], [1/2, 1/2], 5000))
# Out:
# The network thinks action 0 is the most promising....
# [ 1.06961656  0.99923491]
# 0.5054
# [ 60. -48.]
# The network thinks action 0 is the most promising....
# [ 1.0926348   0.95907348]
# 0.5112
# [ 108. -116.]
# The network thinks action 0 is the most promising....
# [ 1.0003252   0.97540849]
# 0.501
# [ -8. -28.]
# The network thinks action 1 is the most promising....
# [ 0.8941552   0.89522415]
# 0.495
# [-200. -100.]
# The network thinks action 1 is the most promising....
# [ 0.96593612  1.08985794]
# 0.4918
# [ -46.  118.]
# The network thinks action 0 is the most promising....
# [ 1.08560908  0.92277318]
# 0.5096
# [ 158.  -34.]
# The network thinks action 1 is the most promising....
# [ 0.94968486  0.98386127]
# 0.4994
# [-66. -54.]
# The network thinks action 0 is the most promising....
# [ 1.06633067  1.00689232]
# 0.5058
# [ 112.   -4.]
# The network thinks action 1 is the most promising....
# [ 0.97014564  1.02546275]
# 0.4948
# [-86.  18.]
# The network thinks action 1 is the most promising....
# [ 0.95916104  0.98269194]
# 0.4996
# [-74. -66.]
# The network thinks action 1 is the most promising....
# [ 1.0360713   1.18052864]
# 0.4936
# [  64.  192.]
# The network thinks action 1 is the most promising....
# [ 0.99851298  1.01115847]
# 0.4968
# [-70.  -6.]
# The network thinks action 1 is the most promising....
# [ 0.96019435  1.04347038]
# 0.494
# [-88.  32.]
# The network thinks action 1 is the most promising....
# [ 0.9118067   1.16826689]
# 0.4814
# [ -44.  328.]
# The network thinks action 0 is the most promising....
# [ 1.0408529   0.90032452]
# 0.5134
# [  98. -170.]
# The network thinks action 0 is the most promising....
# [ 0.97945666  0.94870794]
# 0.499
# [-54. -34.]
# The network thinks action 1 is the most promising....
# [ 0.91968614  0.97624725]
# 0.4964
# [-130.  -58.]
# The network thinks action 0 is the most promising....
# [ 1.00166416  0.97472507]
# 0.5008
# [-18. -34.]
# The network thinks action 1 is the most promising....
# [ 0.96347809  1.00765669]
# 0.4954
# [-86.   6.]
# The network thinks action 1 is the most promising....
# [ 0.98598063  1.02958965]
# 0.4974
# [-12.  40.]
# The network thinks action 0 is the most promising....
# [ 1.08894849  1.00126076]
# 0.504
# [ 64. -16.]
# The network thinks action 1 is the most promising....
# [ 0.93808019  1.10012531]
# 0.4896
# [ -44.  164.]
# The network thinks action 0 is the most promising....
# [ 1.02123797  1.00017524]
# 0.5018
# [ 14. -22.]
# The network thinks action 1 is the most promising....
# [ 0.91973191  0.9732306 ]
# 0.494
# [-136.  -16.]
# The network thinks action 0 is the most promising....
# [ 1.04374969  0.95887846]
# 0.5088
# [  72. -104.]
# The network thinks action 0 is the most promising....
# [ 1.1439836  0.8920725]
# 0.5168
# [ 274.  -62.]
# The network thinks action 0 is the most promising....
# [ 1.02285409  0.95328403]
# 0.5032
# [-26. -90.]
# The network thinks action 1 is the most promising....
# [ 1.00957847  1.01203704]
# 0.4988
# [-14.  10.]
# The network thinks action 0 is the most promising....
# [ 0.96281272  0.95951545]
# 0.4972
# [-82. -26.]
# The network thinks action 0 is the most promising....
# [ 1.05650127  1.03065681]
# 0.5044
# [ 96.   8.]
# The network thinks action 0 is the most promising....
# [ 1.07527316  0.89735329]
# 0.5108
# [ 156.  -60.]
# The network thinks action 1 is the most promising....
# [ 1.06542146  1.12766361]
# 0.5
# [ 80.  80.]
# The network thinks action 0 is the most promising....
# [ 0.99581242  0.89528745]
# 0.502
# [-36. -76.]
# The network thinks action 0 is the most promising....
# [ 1.02903545  0.85950834]
# 0.507
# [ 62. -78.]
# The network thinks action 1 is the most promising....
# [ 0.9434759   0.96578711]
# 0.5012
# [-48. -72.]
# The network thinks action 1 is the most promising....
# [ 0.856547    0.95423472]
# 0.5006
# [-76. -88.]
# The network thinks action 1 is the most promising....
# [ 0.98720026  1.08955944]
# 0.4898
# [ -38.  166.]
# The network thinks action 1 is the most promising....
# [ 0.94896472  1.11850023]
# 0.4832
# [ -84.  252.]
# The network thinks action 1 is the most promising....
# [ 0.93848979  1.04933071]
# 0.4892
# [-126.   90.]
# The network thinks action 1 is the most promising....
# [ 0.95054293  1.13752007]
# 0.4846
# [ -34.  274.]
# The network thinks action 1 is the most promising....
# [ 0.86429167  1.05322444]
# 0.4916
# [ -68.  100.]
# The network thinks action 1 is the most promising....
# [ 0.9374004   1.02793252]
# 0.4952
# [-40.  56.]
# The network thinks action 0 is the most promising....
# [ 1.03522825  1.00833631]
# 0.4984
# [ -6.  26.]
# The network thinks action 1 is the most promising....
# [ 0.92900813  1.02972651]
# 0.4916
# [-124.   44.]
# The network thinks action 0 is the most promising....
# [ 1.05570805  0.92202282]
# 0.5074
# [ 96. -52.]
# The network thinks action 1 is the most promising....
# [ 0.89341098  0.89458644]
# 0.5078
# [ -60. -216.]
# The network thinks action 0 is the most promising....
# [ 1.0542835   1.02715743]
# 0.499
# [  4.  24.]
# The network thinks action 1 is the most promising....
# [ 0.92671782  1.01054788]
# 0.4962
# [-90. -14.]
# The network thinks action 0 is the most promising....
# [ 1.03545773  1.02447355]
# 0.4974
# [-26.  26.]
# The network thinks action 1 is the most promising....
# [ 0.98221034  1.02545094]
# 0.4976
# [-12.  36.]
# The network thinks action 1 is the most promising....
# [ 0.9853695   1.04265058]
# 0.4974
# [-32.  20.]
# The network thinks action 0 is the most promising....
# [ 1.04765821  1.00216269]
# 0.5028
# [ 30. -26.]
# The network thinks action 0 is the most promising....
# [ 1.05543482  0.98443252]
# 0.5024
# [ 38. -10.]
# The network thinks action 1 is the most promising....
# [ 0.9845711   1.00736618]
# 0.4984
# [-48. -16.]
# The network thinks action 1 is the most promising....
# [ 0.99355     1.12921989]
# 0.489
# [ -48.  172.]
# The network thinks action 1 is the most promising....
# [ 0.9327606   0.97816789]
# 0.4982
# [-82. -46.]
# The network thinks action 0 is the most promising....
# [ 0.98702043  0.77709043]
# 0.5042
# [ -34. -118.]
# The network thinks action 0 is the most promising....
# [ 0.99736959  0.96594268]
# 0.5006
# [-48. -60.]
# The network thinks action 1 is the most promising....
# [ 0.92417336  1.02941382]
# 0.4944
# [-64.  48.]
# The network thinks action 1 is the most promising....
# [ 1.02653241  1.18525195]
# 0.4822
# [  -8.  348.]
# The network thinks action 1 is the most promising....
# [ 0.9292118   0.96728331]
# 0.4962
# [-152.  -76.]
# The network thinks action 1 is the most promising....
# [ 0.95385528  0.98039097]
# 0.4986
# [-66. -38.]
# The network thinks action 1 is the most promising....
# [ 0.9806596   1.01395547]
# 0.4994
# [-40. -28.]
# The network thinks action 1 is the most promising....
# [ 0.95583606  1.04954588]
# 0.4908
# [-100.   84.]
# The network thinks action 1 is the most promising....
# [ 0.95484293  1.07680559]
# 0.4914
# [ -30.  142.]
# The network thinks action 1 is the most promising....
# [ 1.0585748   1.14123845]
# 0.4872
# [  18.  274.]
# The network thinks action 0 is the most promising....
# [ 1.03898859  1.03425062]
# 0.5058
# [ 72. -44.]
# The network thinks action 0 is the most promising....
# [ 1.10662258  1.07057977]
# 0.5006
# [ 68.  56.]
# The network thinks action 1 is the most promising....
# [ 0.98173654  1.00242913]
# 0.4998
# [-22. -18.]
# The network thinks action 1 is the most promising....
# [ 0.90815818  1.02692568]
# 0.4932
# [-86.  50.]
# The network thinks action 0 is the most promising....
# [ 1.06621253  0.97770274]
# 0.5054
# [ 64. -44.]
# The network thinks action 0 is the most promising....
# [ 0.95124203  0.94176555]
# 0.4988
# [-94. -70.]
# The network thinks action 1 is the most promising....
# [ 0.95241243  0.97661227]
# 0.498
# [-74. -34.]
# The network thinks action 1 is the most promising....
# [ 0.99919528  1.07323527]
# 0.4964
# [-10.  62.]
# The network thinks action 0 is the most promising....
# [ 0.97845036  0.92039424]
# 0.502
# [-46. -86.]
# The network thinks action 0 is the most promising....
# [ 1.0050987   0.91952974]
# 0.5032
# [ -4. -68.]
# The network thinks action 0 is the most promising....
# [ 0.99309272  0.90941828]
# 0.5012
# [-24. -48.]
# The network thinks action 1 is the most promising....
# [ 0.88884342  1.14101493]
# 0.482
# [ -86.  274.]
# The network thinks action 0 is the most promising....
# [ 0.95068091  0.87567711]
# 0.4982
# [-106.  -70.]
# The network thinks action 0 is the most promising....
# [ 1.04499686  0.92492354]
# 0.5074
# [ 68. -80.]
# The network thinks action 0 is the most promising....
# [ 1.08685899  0.98768294]
# 0.5086
# [ 160.  -12.]
# The network thinks action 1 is the most promising....
# [ 0.92429215  1.05459225]
# 0.494
# [-62.  58.]
# The network thinks action 0 is the most promising....
# [ 1.0367682   0.99137026]
# 0.5038
# [ 60. -16.]
# The network thinks action 1 is the most promising....
# [ 0.93718475  1.03304768]
# 0.4946
# [-52.  56.]
# The network thinks action 1 is the most promising....
# [ 0.94223654  1.00869584]
# 0.4978
# [-78. -34.]
# The network thinks action 0 is the most promising....
# [ 1.08432209  0.98772538]
# 0.5082
# [ 152.  -12.]
# The network thinks action 1 is the most promising....
# [ 0.97566909  1.07792354]
# 0.4924
# [ -26.  126.]
# The network thinks action 0 is the most promising....
# [ 0.9911319   0.98105103]
# 0.4988
# [-58. -34.]
# The network thinks action 1 is the most promising....
# [ 0.84733623  0.95169276]
# 0.4986
# [-118.  -90.]
# The network thinks action 0 is the most promising....
# [ 1.1145066   1.02430594]
# 0.507
# [ 170.   30.]
# The network thinks action 1 is the most promising....
# [ 0.94776481  0.98722792]
# 0.4996
# [-28. -20.]
# The network thinks action 0 is the most promising....
# [ 1.09921193  1.0339309 ]
# 0.5088
# [ 186.   10.]
# The network thinks action 0 is the most promising....
# [ 0.99078506  0.93763512]
# 0.5006
# [-38. -50.]
# The network thinks action 0 is the most promising....
# [ 1.1024369   0.99781561]
# 0.5072
# [ 118.  -26.]
# The network thinks action 0 is the most promising....
# [ 0.96478122  0.86079854]
# 0.4998
# [-86. -82.]
# The network thinks action 0 is the most promising....
# [ 1.03086412  0.97036386]
# 0.5046
# [ 12. -80.]
# The network thinks action 0 is the most promising....
# [ 1.02057183  0.99556875]
# 0.5018
# [ 14. -22.]
# The network thinks action 1 is the most promising....
# [ 1.0058651   1.03417742]
# 0.4974
# [-18.  34.]
# The network thinks action 1 is the most promising....
# [ 0.94707155  1.04201877]
# 0.495
# [-70.  30.]
# The network thinks action 1 is the most promising....
# [ 0.98279065  1.00555229]
# 0.4952
# [-98.  -2.]

# %%
# Out:
# 54

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource, LabelSet, Legend, HoverTool
from bokeh.palettes import Category20

data = pd.DataFrame(hist).T
data = data.cumsum().div(pd.Series(data.index)+1, axis='index')

TOOLS = "crosshair,pan,wheel_zoom,reset,tap,save,box_select,hover"

numlines = len(data.columns)
#mypalette = Category20[numlines]

p = figure(tools=TOOLS, plot_width=800, plot_height=700)

p.multi_line(xs=[data.index.values]*numlines,
             ys=[data[name].values for name in data])

p.title.text = "Evolution of SGD Agent Best Response Play"
p.title.text_font_size = "20px"

p.yaxis.axis_label = 'Cumulative Frequency'
p.xaxis.axis_label = 'Episodes'

show(p)
