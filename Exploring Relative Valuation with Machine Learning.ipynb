# %% [markdown]
# # Introduction to Relative Valuation using Market Comparables
#
# **Quentin Batista**
# *The University of Tokyo*
#
# Relative valuation is a popular technique which relies on the market value of similar assets to price a given asset. For example, if you want to price a laundry business, you might want to calculate the price to earnings ratio of other similar businesses and multiply this ratio by the earnings of the laundry business to obtain a valuation. Sheridan and Martin describe this methodology as a 4-step process:
#
# **Step 1:** Identify similar or comparable investments and recent market prices for each.
#
# **Step 2:** Calculate a valuation metric for use in valuing the asset.
#
# **Step 3:** Calculate an initial estimate of value.
#
# **Step 4:** Refine or tailor your initial valuation estimate to the specific characteristics of the investment.
#
# Some of the most commonly used multiples are:
#
# - Price to earnings (P/E)
#
# - Market to book value of equity
#
# - Enterprise Value (EV) to EBITDA
#
# - Enterprise Value (EV) to revenue
#
# - Enterprise Value (EV) to cash flow
#
# This list is not exhaustive, and it is possible for you to create your own multiple. This is particularly popular in the technology sector where analysts have come up with multiples such as Enterprise Value to unique visitors or website hits. In doing so, you must ensure that the components of the multiple are consistent with each other. For example, you might consider using the price to sales ratio as a valuation multiple. However, an implicit assumption behind this multiple is that comparable companies have identical capital structures, which is very rarely the case in practice. When this assumption is violated, the multiple becomes inconsistent because it is impacted by the amount of debt that a company has relative to its equity.
#
# Finally, a key step in applying this methodology is to determine which multiple is appropriate for the asset you are trying to value. For example, valuing young firms and startups using the P/E ratio is likely to be inappropriate if those firms have negative or highly volatile earnings. Instead, using the EV to sales ratio would likely give a better estimate. Additionally, it is important to realize that these multiples have different characteristics. While EV to EBITDA ignores the firm's CapEx, depreciation, and capital structure, while the P/E ratio takes those into account. Using these multiples concurrently allows you to see the big picture and understand what is driving the valuation of an asset.

# %% [markdown]
# # Systematic Relative Valuation Using Machine Learning
#
# ### Objective
#
# In this notebook, we systematize the methodology introduced above for companies in the S&P 500 using two different Machine Learning approaches. First, we replicate Gael Varoquaux's analysis on scikit-learn which extracts a graphical structure from the correlation of intraday variations and then applies Affinity Propagation to group together stocks that behave similarly. Second, we analyze the companies' latest 10K using the Doc2Vec implementation in gensim to quantify similarity. In the first case, we use the average multiple in each cluster to value each company. In the second case, we pick the top 3 comparable companies and normalize the similarity measures as weights to compute the average comparable multiple. We then apply this multiple to each company's financials to obtain a valuation.
#
# The hope of using this approach is to capture relationships between companies that human analysts would not be able to perceive. Reading through the financial statements of all the companies in the S&P 500 and forming an opinion about how these companies relate to each other would be an extremely time-consuming process. As a result, most analysts on the Street cover a specific industry group, and therefore, they might not realize that a company they are researching is actually very similar to a company in classified in a different industry group. By using Machine Learning, we can alleviate this issue, and hopefully, gain some valuable insights about the stock market structure.
#
# ### Data
#
# We scrape the list of companies in the S&P 500, their ticker and CIK code from Wikipedia. We then use the CIK code to scrape the latest 10K from EDGAR. There are 505 companies in the Wikipedia list because some companies trade under multiple symbols (for example, Discovery Communications Inc.). A few companies' financial statements are not available on EDGAR for various reasons -- we ignore those companies. We clean the data by removing "Table of Contents" markers when they exist, page numbers, line breaks, punctuations and numbers from the statements. We scrape company fundamentals and their historical prices from Yahoo! Finance. Note that we drop the companies with negative multiples to simplify valuation. While Yahoo! Finance might not be a particularly reliable source for getting data about company fundamentals, it is the best among free data sources.

# %% [markdown]
# ## Required Packages

# %%
# !pip install numpy
# !pip install pandas
# !pip install beautifulsoup4
# !pip install gensim
# !pip install nltk
# !pip install sklearn
# !pip install bokeh
# !pip install pandas_datareader
# !pip install datetime

# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen
from collections import namedtuple
from gensim.models import doc2vec
from gensim.similarities import docsim
from gensim import corpora
import itertools
from string import punctuation, digits
from nltk import word_tokenize
from nltk.corpus import stopwords
from sklearn.manifold import TSNE
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource, LabelSet, Legend, HoverTool
from bokeh.palettes import all_palettes
from pandas_datareader.data import DataReader
from datetime import date

# %% [markdown]
# ## Data Scraping

# %% [markdown]
# ### Scraping 10Ks from EDGAR

# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen


def table_extractor(soup): # Extract the tables from a soup object
    for table in soup.find_all("table"):
        table.extract()
    return soup


sp_500_wiki_link = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
soup_wiki = BeautifulSoup(urlopen('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'), 'html.parser')
table_wiki = soup_wiki.find("table", { "class" : "wikitable sortable" })

# Fail now if the right table hasn't been found
header = table_wiki.findAll('th')
if header[0].string != "Ticker symbol" or header[1].string != "Security":
    raise Exception("Can't parse wikipedia's table!") 
    
# Retreive the values in the table
records = []
rows = table_wiki.findAll('tr')
for row in rows:
    fields = row.findAll('td')
    if fields:
        # Get info and SEC company link
        symbol = fields[0].string
        wiki_link = "https://en.wikipedia.org/wiki" + fields[1].a.get('href')
        CIK = fields[7].string
        sec_company_link = "https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=" + CIK + \
                           "&type=10-K&dateb=&owner=include&count=40"
        name = fields[1].a.string
        sector = fields[3].string

        # Get link for the page with latest 10-K related filings
        soup_filings = BeautifulSoup(urlopen(sec_company_link), 'html.parser')
        table_filings = soup_filings.find("table", { "class" : "tableFile2" })
        try:
            filings_page_link = "https://www.sec.gov" + table_filings.a.get('href') # Get the latest filing page
            
            # Get the link for the latest 10K
            soup_filings_page = BeautifulSoup(urlopen(filings_page_link), 'html.parser')
            table_filings_page = soup_filings_page.find("table", { "class" : "tableFile" })
            _10K_link = "https://www.sec.gov" + table_filings_page.a.get('href')
            
            # Extracting the text from the latest 10K
            try: 
                soup_latest_10K = BeautifulSoup(urlopen(_10K_link).read(), 'html.parser')
                soup_latest_10K = table_extractor(soup_latest_10K)
                _latest_10K_txt = soup_latest_10K.get_text()

            except:
                # If the 10K is not available, return N/A
                _latest_10K_txt = np.nan
                
        except:
            # If the filings are not available, return N/A
            _10K_link = np.nan
            _latest_10K_txt = np.nan
        
        # Append results
        records.append([symbol, wiki_link, name, sector, sec_company_link, CIK, _latest_10K_txt])
        
headers = ['Symbol', 'Wikipedia Link', 'Name', 'Sector', 'SEC Filings Link', 'CIK', 'Latest 10K']
data = pd.DataFrame(records, columns=headers)

# Correct ambiguous tickers
ambiguous_tickers = ['BRK.B', 'BF.B']
corrected_tickers = ['BRK-B', 'BF-B']

for i, ticker in enumerate(ambiguous_tickers):
    data['Symbol'] = data['Symbol'].replace(ticker, corrected_tickers[i])

# %% [markdown]
# ### Scraping Fundamentals from Yahoo! Finance

# %%
def unit_converter(data):
    billion = 1_000_000_000
    million = 1_000_000
    if data[-1] == 'B':
        return float(data[:-1])*billion
    elif data[-1] == 'M':
        return float(data[:-1])*million
    else:
        return float(data)

    
items = ['Enterprise Value', 'Enterprise Value/Revenue', 'Enterprise Value/EBITDA',
         'Revenue', 'EBITDA', 'Diluted EPS', 'Trailing P/E']

for item in items:
    data[item] = np.nan
    
for i, ticker in enumerate(data['Symbol']):
    key_stats_link = 'https://finance.yahoo.com/quote/' + ticker + '/key-statistics?p=' + ticker
    key_stats_soup = BeautifulSoup(urlopen(key_stats_link).read(), 'html.parser').findAll('td')
    for j, row in enumerate(key_stats_soup):
        for item in items:
            try: 
                if item == row.span.string:
                    data.loc[i, item] = unit_converter(key_stats_soup[j+1].string) # Dangerous
            except:
                next

# %% [markdown]
# ### Scraping Historical Prices from Yahoo! Finance

# %%
from pandas_datareader.data import DataReader
from datetime import date

start = date(2013, 1, 2)
end = date.today()

data_source = 'yahoo'

# Sometimes fail -- retry if it does
historical_prices_panel = DataReader(data['Symbol'], data_source, start, end, retry_count=5)

# Current price is last close
last_price = historical_prices_panel['Close'].tail(1).T.iloc[:, 0].rename('Current Price')
data = data.join(last_price, on='Symbol')

close_price = historical_prices_panel['Close']
open_price = historical_prices_panel['Open']

# %%
# Uncomment to save the data
# data.to_csv('10K_data.csv')
# historical_prices_panel['Close'].to_csv('close_price_data.csv')
# historical_prices_panel['Open'].to_csv('open_price_data.csv')

# %% [markdown]
# ## Data Cleaning and Preprocessing

# %%
# Uncomment to read the data
# data = pd.read_csv('10K_data.csv')
# close_price = pd.read_csv('close_price_data.csv')
# open_price = pd.read_csv('open_price_data.csv')

# %%
# Remove companies without filings
no_filings_data = data[data['Latest 10K'].isnull()]
data = data[~data['Latest 10K'].isnull()]

# Remove duplicates (keep first)
data = data.drop_duplicates(keep='first')

# Drop Google duplicate
data = data[data['Symbol'] != 'GOOG']

# Drop NA rows (about 60 companies)
data = data.dropna()

# Drop companies with negative EPS or EBITDA (about 30 companies)
data = data[(data[['EBITDA', 'Diluted EPS']] > 0).all(1)]

# Reset index
data = data.reset_index(drop=True)

# %%
from collections import namedtuple
from nltk import word_tokenize
from nltk.corpus import stopwords
from string import punctuation, digits


def _10K_string_cleaner(_10K):
    _10K = _10K.lower() # Lowercase the text
    stopchar = punctuation + digits + '’“”'
    for ch in stopchar:
        _10K = _10K.replace(ch, ' ') # Replace stopchar by whitespace
    _10K = word_tokenize(_10K) # Tokenize
    _10K = [word for word in _10K if word not in stopwords.words('english')] # Remove stopwords
    return _10K


corpus = []
analyzedDocument = namedtuple('AnalyzedDocument', 'words tags')
for i, text in enumerate(data['Latest 10K']):
    corpus.append(analyzedDocument(_10K_string_cleaner(text), [i]))

# %% [markdown]
# ## Doc2Vec Model
#
# Doc2Vec is an implementation of the Paragraph Vector unsupervised learning algorithm proposed by Quoc Le and Tomas Mikolov for learning fixed-length feature representations from variable-length pieces of texts. It aims to overcome some of the weaknesses of the more traditional bag-of-words (BOW) methodology.

# %%
from gensim.models import doc2vec
from gensim.similarities import docsim

model_NLP = doc2vec.Doc2Vec(corpus, size = 500, window = 300, min_count = 1, workers = 4)

# %%
import itertools

similarity_matrix_NLP = np.empty(0)
length_docvecs = len(model_NLP.docvecs)
for item in itertools.product(range(length_docvecs), range(length_docvecs)):
    similarity_matrix_NLP = np.append(similarity_matrix_NLP, model_NLP.docvecs.similarity(*item))
    
similarity_matrix_NLP = similarity_matrix_NLP.reshape((length_docvecs, length_docvecs))

# %% [markdown]
# ## Visualization
#
# ### Stock Market Structure
#
# We use three different methodologies for visualizing the structure of the stock market. First, we create a simple scatter plot of the companies' EV/EBITDA against their P/E ratio. Second, we use the correlation matrix of the S&P 500 stocks between the start of 2013 and the last price. Third, we use the similarity matrix outputted from the Doc2Vec model. In the last two cases, t-SNE is used for dimensionality reduction.

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource, LabelSet, Legend, HoverTool
from bokeh.palettes import all_palettes

output_notebook()

category_items = data['Sector'].unique()
palette = all_palettes['Viridis'][len(category_items)]
colormap = dict(zip(category_items, palette))
data['Color'] = data['Sector'].map(colormap)

TOOLS = "crosshair,pan,wheel_zoom,reset,tap,save,box_select"

source = ColumnDataSource(dict(x = data['Trailing P/E'],
                               y = data['Enterprise Value/EBITDA'],
                               color = data['Color'],
                               label = data['Name'],
                               ticker = data['Symbol'],
                               sector = data['Sector']))

hover = HoverTool(tooltips=[
    ("index", "$index"),
    ("name", "@label"),
    ("sector", "@sector"),
    ("ticker", "@ticker"),
    ("(x,y)", "($x, $y)"),
])

p = figure(tools=[TOOLS, hover], plot_width=800, plot_height=700)

labels = LabelSet(x='x', y='y', text='label', source=source, text_font_size='8pt')

p.scatter(x='x', y='y', color='color', legend='sector', source=source) # Remove "legend='sector'," to remove legend

p.title.text = "Current Valuation Structure"
p.title.text_font_size = "25px"

#p.add_layout(labels) # Comment this line to remove labels

p.xaxis.axis_label = 'Trailing P/E'
p.yaxis.axis_label = 'EV/EBITDA'

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f0916c11-9fe3-43df-b65a-82a9dff2f811">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="58b4a51f-5ddf-4e2c-8c78-1b34ae77f751"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("58b4a51f-5ddf-4e2c-8c78-1b34ae77f751");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("58b4a51f-5ddf-4e2c-8c78-1b34ae77f751");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '58b4a51f-5ddf-4e2c-8c78-1b34ae77f751' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"04e8e01f-11ae-40bd-a8ef-1becbc1782f1":{"roots":{"references":[{"attributes":{"plot":{"id":"8a2d8cf8-4369-491e-bfaa-b47748aaccff","subtype":"Figure","type":"Plot"}},"id":"a9a28f00-fcae-4f2c-b573-d004289b388b","type":"SaveTool"},{"attributes":{"callback":null},"id":"02093666-4607-4f7c-af43-78a854977760","type":"DataRange1d"},{"attributes":{"callback":null,"overlay":{"id":"bbc4668b-c49b-4b2d-bc10-b174338068f7","type":"BoxAnnotation"},"plot":{"id":"8a2d8cf8-4369-491e-bfaa-b47748aaccff","subtype":"Figure","type":"Plot"},"renderers":[{"id":"02d67100-a87f-45e0-91dd-68855a93cbdf","type":"GlyphRenderer"}]},"id":"d85fdd4c-2c1a-4475-94e5-167c3f48ea91","type":"BoxSelectTool"},{"attributes":{},"id":"a52649c1-502a-43b1-a656-80ea0006da46","type":"BasicTickFormatter"},{"attributes":{"axis_label":"EV/EBITDA","formatter":{"id":"a52649c1-502a-43b1-a656-80ea0006da46","type":"BasicTickFormatter"},"plot":{"id":"8a2d8cf8-4369-491e-bfaa-b47748aaccff","subtype":"Figure","type":"Plot"},"ticker":{"id":"97e52062-8761-40d2-820b-5137bc03034e","type":"BasicTicker"}},"id":"155e01cc-30cb-4abc-b1bf-9249ca17973e","type":"LinearAxis"},{"attributes":{"items":[{"id":"7960b023-9941-496a-8c16-27fbdda3d998","type":"LegendItem"}],"plot":{"id":"8a2d8cf8-4369-491e-bfaa-b47748aaccff","subtype":"Figure","type":"Plot"}},"id":"3b95e1e5-a641-4666-8785-cfb7808f4b06","type":"Legend"},{"attributes":{"data_source":{"id":"ccdf103b-3704-44cf-8e5d-3509ddf3a8d0","type":"ColumnDataSource"},"glyph":{"id":"42df95e1-464f-49d4-bc1f-82c765c8da75","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9472833e-0711-4d59-8e92-3791bc7509d2","type":"Circle"},"selection_glyph":null},"id":"02d67100-a87f-45e0-91dd-68855a93cbdf","type":"GlyphRenderer"},{"attributes":{"label":{"field":"sector"},"renderers":[{"id":"02d67100-a87f-45e0-91dd-68855a93cbdf","type":"GlyphRenderer"}]},"id":"7960b023-9941-496a-8c16-27fbdda3d998","type":"LegendItem"},{"attributes":{},"id":"073a4f3d-3d09-4279-bb7c-c2073d40ed2a","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"f76ca5ba-7d82-437d-b363-fe3e35ccc810","type":"LinearAxis"}],"left":[{"id":"155e01cc-30cb-4abc-b1bf-9249ca17973e","type":"LinearAxis"}],"plot_height":700,"plot_width":800,"renderers":[{"id":"f76ca5ba-7d82-437d-b363-fe3e35ccc810","type":"LinearAxis"},{"id":"35c2c12f-89c1-4b89-a428-8d598d54ba09","type":"Grid"},{"id":"155e01cc-30cb-4abc-b1bf-9249ca17973e","type":"LinearAxis"},{"id":"c2349161-ba04-49f8-837d-c7f64ed684ef","type":"Grid"},{"id":"bbc4668b-c49b-4b2d-bc10-b174338068f7","type":"BoxAnnotation"},{"id":"3b95e1e5-a641-4666-8785-cfb7808f4b06","type":"Legend"},{"id":"02d67100-a87f-45e0-91dd-68855a93cbdf","type":"GlyphRenderer"}],"title":{"id":"2451df0f-8ed9-459f-b805-fa350332338c","type":"Title"},"tool_events":{"id":"8ff2933d-3255-48bf-b61f-e0d89bb8e11e","type":"ToolEvents"},"toolbar":{"id":"3ac940c0-ef5a-4feb-8b00-4532f399b8b3","type":"Toolbar"},"x_range":{"id":"02093666-4607-4f7c-af43-78a854977760","type":"DataRange1d"},"y_range":{"id":"ac64ca2d-ebeb-4c04-b19b-8dd836bc0224","type":"DataRange1d"}},"id":"8a2d8cf8-4369-491e-bfaa-b47748aaccff","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","y","color","label","ticker","sector"],"data":{"color":["#440154","#482374","#482374","#404387","#404387","#440154","#404387","#345E8D","#482374","#29788E","#29788E","#482374","#208F8C","#404387","#440154","#208F8C","#22A784","#482374","#440154","#482374","#404387","#42BE71","#29788E","#404387","#79D151","#345E8D","#42BE71","#440154","#42BE71","#22A784","#29788E","#482374","#440154","#482374","#404387","#404387","#BADE27","#404387","#482374","#29788E","#440154","#22A784","#404387","#404387","#79D151","#29788E","#FDE724","#404387","#345E8D","#22A784","#208F8C","#208F8C","#482374","#482374","#482374","#29788E","#345E8D","#482374","#29788E","#29788E","#440154","#345E8D","#22A784","#482374","#482374","#404387","#79D151","#440154","#404387","#404387","#79D151","#482374", ...

# %% [markdown]
# There is a clear positive relationship between a company's EV/EBITDA and P/E ratio. While most companies are clustered in the bottom left quadrant, there are a few outliers. We choose to keep those outliers for valuation because they still provide valuable information about companies as we will see later.

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, random_state=0, perplexity=10.0)
Y = tsne.fit_transform(similarity_matrix_NLP)

plotting_df = pd.concat([data[['Name', 'Symbol', 'Sector', 'Color']],
                         pd.DataFrame(Y, columns=['x', 'y'])], axis=1)

source = ColumnDataSource(dict(x = plotting_df['x'],
                               y = plotting_df['y'],
                               color = plotting_df['Color'],
                               label = plotting_df['Name'],
                               ticker = plotting_df['Symbol'],
                               sector = plotting_df['Sector']))

hover = HoverTool(tooltips=[
    ("index", "$index"),
    ("name", "@label"),
    ("sector", "@sector"),
    ("ticker", "@ticker"),
    ("(x,y)", "($x, $y)"),
])

p = figure(tools=[TOOLS, hover], plot_width=800, plot_height=700)

labels = LabelSet(x='x', y='y', text='label', source=source, text_font_size='8pt')

p.scatter(x='x', y='y', color='color', legend='sector', source=source)

p.title.text = "2D Company Similarity Visualization (NLP)"
p.title.text_font_size = "25px"

#p.add_layout(labels) # Comment this line to remove labels

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="29ed5f57-17e4-49b1-b291-69bdcb767635"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("29ed5f57-17e4-49b1-b291-69bdcb767635");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("29ed5f57-17e4-49b1-b291-69bdcb767635");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '29ed5f57-17e4-49b1-b291-69bdcb767635' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"024ff70d-49a5-4852-a5c4-cfc20eabe517":{"roots":{"references":[{"attributes":{"label":{"field":"sector"},"renderers":[{"id":"52ac2a21-8100-411e-bf82-5ca54fdf4479","type":"GlyphRenderer"}]},"id":"ccee3d71-d8cb-4092-a247-a67e7ea8d07a","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y","color","label","ticker","sector"],"data":{"color":["#440154","#482374","#482374","#404387","#404387","#440154","#404387","#345E8D","#482374","#29788E","#29788E","#482374","#208F8C","#404387","#440154","#208F8C","#22A784","#482374","#440154","#482374","#404387","#42BE71","#29788E","#404387","#79D151","#345E8D","#42BE71","#440154","#42BE71","#22A784","#29788E","#482374","#440154","#482374","#404387","#404387","#BADE27","#404387","#482374","#29788E","#440154","#22A784","#404387","#404387","#79D151","#29788E","#FDE724","#404387","#345E8D","#22A784","#208F8C","#208F8C","#482374","#482374","#482374","#29788E","#345E8D","#482374","#29788E","#29788E","#440154","#345E8D","#22A784","#482374","#482374","#404387","#79D151","#440154","#404387","#404387","#79D151","#482374","#29788E","#345E8D","#345E8D","#440154","#22A784","#345E8D","#482374","#482374","#42BE71","#FDE724","#482374","#345E8D","#BADE27","#345E8D","#29788E","#79D151","#482374","#BADE27","#29788E","#440154","#404387","#79D151","#29788E","#42BE71","#404387","#79D151","#345E8D","#79D151","#BADE27","#42BE71","#79D151","#482374","#404387","#79D151","#22A784","#404387","#440154","#440154","#79D151","#345E8D","#482374","#345E8D","#482374","#440154","#345E8D","#440154","#BADE27","#22A784","#345E8D","#345E8D","#345E8D","#345E8D","#345E8D","#42BE71","#440154","#79D151","#42BE71","#22A784","#42BE71","#208F8C","#440154","#404387","#208F8C","#42BE71","#482374","#404387","#440154","#440154","#22A784","#22A784","#22A784","#79D151","#42BE71","#42BE71","#345E8D","#440154","#482374","#22A784","#BADE27","#404387","#404387","#440154","#22A784","#440154","#404387","#404387","#404387","#440154","#440154","#208F8C","#345E8D","#345E8D","#440154","#440154","#208F8C","#345E8D","#404387","#440154","#440154","#22A784","#345E8D","#345E8D","#404387","#345E8D","#440154","#345E8D","#345E8D","#404387","#29788E","#345E8D","#482374","#22A784","#482374","#79D151","#404387","#482374","#345E8D","#440154","#79D151","#22A784","#482374","#482374","#440154","#440154","#482374","#440154","#404387","#29788E","#404387","#345E8D","#208F8C","#404387","#482374","#29788E","#440154","#440154","#79D151","#482374","#404387","#440154","#79D151","#79D151","#22A784","#BADE27","#404387","#345E8D","#79D151","#79D151","#345E8D","#440154","#404387","#345E8D","#345E8D","#29788E","#482374","#29788E","#345E8D","#440154","#29788E","#345E8D","#208F8C","#22A784","#345E8D","#BADE27","#345E8D","#29788E","#208F8C","#440154","#404387","#345E8D","#79D151","#345E8D","#482374","#482374","#482374","#29788E","#482374","#345E8D","#404387","#404387","#22A784","#345E8D","#79D151","#79D151","#208F8C","#79D151","#29788E","#208F8C","#404387","#482374","#29788E","#404387","#404387","#345E8D","#BADE27","#42BE71","#440154","#345E8D","#42BE71","#345E8D","#440154","#440154","#345E8D","#208F8C","#404387","#345E8D","#BADE27","#345E8D","#BADE27","#404387","#440154","#208F8C","#440154","#482374","#404387","#404387","#440154","#79D151","#482374","#482374","#42BE71","#79D151","#BADE27","#42BE71","#BADE27","#208F8C","#42BE71","#208F8C","#345E8D","#29788E","#79D151","#29788E","#22A784","#29788E","#42BE71","#22A784","#345E8D","#345E8D","#440154","#404387","#482374","#482374","#BADE27","#440154","#22A784","#404387","#22A784","#482374","#440154","#482374","#440154","#440154","#440154","#440154","#345E8D","#345E8D","#22A784","#42BE71","#BADE27","#345E8D","#404387","#208F8C","#42BE71","#208F8C","#345E8D","#22A784","#404387","#22A784","#345E8D","#42BE71","#440154","#29788E","#345E8D","#345E8D","#482374","#404387","#79D151","#29788E","#345E8D","#345E8D","#404387","#BADE27","#404387","#440154","#482374","#345E8D","#345E8D","#345E8D","#29788E", ...

# %% [markdown]
# While companies are mostly clustered by their industry groups, this analysis seems to capture relationships between companies which go beyond those. The fact that companies such as Activision Blizzard and Electronic Arts are close to each other suggests that the model is doing something right. However, note that it is possible that the model relies on trivial factors, for example, attributing a high similarity score to companies whose financial statements have the same auditor (say, because the writing style is similar).

# %%
from sklearn import cluster, covariance

# This code was adapted from Gael Varoquaux's work (see references)

# Calculate intraday variation
variation_df = close_price - open_price
variation_df = variation_df.T

# Get name, sector and color from the data dataframe
variation_df = data[['Symbol', 'Name', 'Sector', 'Color']].join(variation_df.reindex(data['Symbol']), on='Symbol')

# Drop rows with NAs
variation_df = variation_df.dropna(axis=0)

# Data for the model
var_data = variation_df.drop(['Symbol', 'Name', 'Sector', 'Color'], axis=1).T

# Learn a graphical structure from the correlations
edge_model = covariance.GraphLassoCV()

# Standardize the time series: using correlations rather than covariance is more efficient for structure recovery
var_data /= var_data.std(axis=0)
edge_model.fit(var_data)

# Cluster using affinity propagation
_, labels = cluster.affinity_propagation(edge_model.covariance_)
n_labels = labels.max()

variation_df['Cluster'] = np.nan

for i in range(n_labels + 1):
    variation_df.loc[labels == i, 'Cluster'] = i + 1
    print('Cluster %i: %s' % ((i + 1), ', '.join(variation_df['Name'][labels == i])))

# Find a low-dimension embedding for visualization: find the best position of the nodes (the stocks) on a 2D plane
embedding = tsne.fit_transform(var_data.T)

# Display a graph of the partial correlations
partial_correlations = edge_model.precision_.copy()
d = 1 / np.sqrt(np.diag(partial_correlations))
partial_correlations *= d
partial_correlations *= d[:, np.newaxis]
non_zero = (np.abs(np.triu(partial_correlations, k=1)) > 0.06)

# Plot the edges
start_idx, end_idx = np.where(non_zero)
segments = [[embedding.T[:, start], embedding.T[:, stop]] for start, stop in zip(start_idx, end_idx)]
values = np.abs(partial_correlations[non_zero])
# Out:
# /Users/QBatista/anaconda/lib/python3.6/site-packages/numpy/linalg/linalg.py:1757: RuntimeWarning: invalid value encountered in slogdet
#   sign, logdet = _umath_linalg.slogdet(a, signature=signature)
# /Users/QBatista/anaconda/lib/python3.6/site-packages/sklearn/covariance/graph_lasso_.py:230: RuntimeWarning: invalid value encountered in multiply
#   * coefs)
# /Users/QBatista/anaconda/lib/python3.6/site-packages/sklearn/covariance/graph_lasso_.py:232: RuntimeWarning: invalid value encountered in multiply
#   * coefs)
# Cluster 1: Agilent Technologies Inc, PerkinElmer, Thermo Fisher Scientific, Verisign Inc.
# Cluster 2: Adobe Systems Inc, Alphabet Inc Class A, Amazon.com Inc, eBay, Expedia Inc., Facebook, Inc., Microsoft Corp., Priceline.com Inc
# Cluster 3: American Tower Corp A, Crown Castle International Corp., SBA Communications
# Cluster 4: Aetna Inc, Anthem Inc., Centene Corporation, CIGNA Corp., Humana Inc., United Health Group Inc.
# Cluster 5: Aon plc, Marsh & McLennan, Willis Towers Watson
# Cluster 6: Archer-Daniels-Midland Co
# Cluster 7: Advance Auto Parts, AutoZone Inc, O'Reilly Automotive
# Cluster 8: Apartment Investment & Management, AvalonBay Communities, Inc., Equity Residential, Essex Property Trust, Inc., Mid-America Apartments, UDR Inc
# Cluster 9: Avery Dennison Corp, Ball Corp, Packaging Corporation of America, Sealed Air
# Cluster 10: Block H&R
# Cluster 11: BorgWarner, Delphi Automotive, Goodyear Tire & Rubber, LKQ Corporation
# Cluster 12: AmerisourceBergen Corp, Cardinal Health, CVS Health, Express Scripts, Henry Schein, McKesson Corp., Patterson Companies
# Cluster 13: AbbVie Inc., Alexion Pharmaceuticals, Amgen Inc, Biogen Inc., Bristol-Myers Squibb, Celgene Corp., Illumina Inc, Mylan N.V., Regeneron, Vertex Pharmaceuticals Inc
# Cluster 14: Chevron Corp., Exxon Mobil Corp., Occidental Petroleum, ONEOK, Schlumberger Ltd., TechnipFMC, Williams Cos.
# Cluster 15: Chipotle Mexican Grill
# Cluster 16: The Clorox Company, Colgate-Palmolive, Estee Lauder Cos., Kimberly-Clark, PepsiCo Inc., Philip Morris International, Procter & Gamble
# Cluster 17: Charter Communications, Comcast Corp.
# Cluster 18: Cimarex Energy, Concho Resources, Devon Energy, Newfield Exploration Co, Pioneer Natural Resources, Range Resources Corp.
# Cluster 19: Alaska Air Group Inc, American Airlines Group, Delta Air Lines, Southwest Airlines, United Continental Holdings
# Cluster 20: Discovery Communications, Discovery Communications, Viacom Inc.
# Cluster 21: Dish Network
# Cluster 22: Dollar General, Dollar Tree, Kroger Co.
# Cluster 23: Albemarle Corp, Eastman Chemical, FMC Corporation, LyondellBasell, The Mosaic Company, Nucor Corp.
# Cluster 24: Activision Blizzard, Electronic Arts
# Cluster 25: F5 Networks, Juniper Networks
# Cluster 26: Accenture plc, Automatic Data Processing, Cognizant Technology Solutions, Equifax Inc., Fidelity National Information Services, Fiserv Inc, Gartner Inc, Intuit, Paychex Inc., Verisk Analytics
# Cluster 27: Flowserve Corporation, Fluor Corp., Freeport-McMoRan Inc., Jacobs Engineering Group, Quanta Services Inc.
# Cluster 28: Carmax Inc, Ford Motor, General Motors
# Cluster 29: Home Depot, Lowe's Cos., Newell Brands, Tractor Supply Company
# Cluster 30: 3M Company, Amphenol Corp, Boeing Company, CA, Inc., Cintas Corporation, Corning Inc., Danaher Corp., Genuine Parts, Honeywell Int'l Inc., Illinois Tool Works, Monsanto Co., Republic Services Inc, Rockwell Collins, Roper Technologies, Snap-On Inc., Textron Inc., United Technologies, Western Union Co
# Cluster 31: CME Group Inc., Intercontinental Exchange, Nasdaq, Inc.
# Cluster 32: Interpublic Group, Omnicom Group
# Cluster 33: Applied Materials Inc, KLA-Tencor Corp., Lam Research, Nvidia Corporation
# Cluster 34: Lennar Corp., Pulte Homes Inc.
# Cluster 35: General Dynamics, L-3 Communications Holdings, Lockheed Martin Corp., Northrop Grumman Corp., Raytheon Co.
# Cluster 36: Host Hotels & Resorts, Marriott Int'l., Wyndham Worldwide
# Cluster 37: Acuity Brands Inc, Fortune Brands Home & Security, Leggett & Platt, Masco Corp., Mohawk Industries, Vulcan Materials
# Cluster 38: Akamai Technologies Inc, Alliance Data Systems, Cerner, Global Payments Inc, Mastercard Inc., Oracle Corp., Red Hat Inc., S&P Global, Inc., Visa Inc.
# Cluster 39: Altria Group Inc, Brown-Forman Corp., Campbell Soup, Conagra Brands, Dr Pepper Snapple Group, The Hershey Company, Hormel Foods Corp., JM Smucker, Kellogg Co., McCormick & Co., Mondelez International, Monster Beverage, Tyson Foods
# Cluster 40: MGM Resorts International, Wynn Resorts
# Cluster 41: Constellation Brands, Molson Coors Brewing Company
# Cluster 42: Gap Inc., Kohl's, Macy's Inc., Nordstrom
# Cluster 43: CSX Corp., Kansas City Southern, Norfolk Southern Corp., Union Pacific
# Cluster 44: AMETEK Inc, Caterpillar Inc., Cummins Inc., Deere & Co., Dover Corp., Eaton Corporation, Emerson Electric Company, Fastenal Co, FLIR Systems, Harley-Davidson, Ingersoll-Rand PLC, PACCAR Inc., Parker-Hannifin, Pentair Ltd., Rockwell Automation Inc., Stanley Black & Decker, United Rentals, Inc., Xylem Inc.
# Cluster 45: Allergan, Plc, Johnson & Johnson, Lilly (Eli) & Co., Merck & Co., Pfizer Inc.
# Cluster 46: Air Products & Chemicals Inc, Ecolab, Intl Flavors & Fragrances, PPG Industries, Praxair Inc., Sherwin-Williams
# Cluster 47: Affiliated Managers Group Inc, AFLAC Inc, Ameriprise Financial, Assurant Inc, Berkshire Hathaway, BlackRock, CBRE Group, Hartford Financial Svc.Gp., International Business Machines, Leucadia National Corp., Lincoln National, Loews Corp., MetLife Inc., Principal Financial Group, Prudential Financial, Robert Half International, T. Rowe Price Group, TE Connectivity Ltd., Torchmark Corp., Unum Group
# Cluster 48: Extra Space Storage, Public Storage
# Cluster 49: Digital Realty, Duke Realty Corp, Equinix, Federal Realty Investment Trust, General Growth Properties Inc., Macerich, Prologis, Realty Income Corporation, Regency Centers Corporation, Simon Property Group Inc
# Cluster 50: Carnival Corp., Royal Caribbean Cruises Ltd
# Cluster 51: NetApp, Seagate Technology, Western Digital
# Cluster 52: Signet Jewelers
# Cluster 53: Darden Restaurants, McDonald's Corp., Starbucks Corp., Yum! Brands Inc
# Cluster 54: Abbott Laboratories, Bard (C.R.) Inc., Baxter International Inc., Becton Dickinson, Boston Scientific, The Cooper Companies, Edwards Lifesciences, Hologic, Intuitive Surgical Inc., Medtronic plc, Quest Diagnostics, ResMed, Stryker Corp., Varian Medical Systems, Zimmer Biomet Holdings
# Cluster 55: ANSYS, Cadence Design Systems, Synopsys Inc.
# Cluster 56: Analog Devices, Inc., Apple Inc., Broadcom, Cisco Systems, Intel Corp., Microchip Technology, Motorola Solutions Inc., QUALCOMM Inc., Skyworks Solutions, Texas Instruments, Xilinx Inc
# Cluster 57: Foot Locker Inc, L Brands Inc., Ross Stores, TJX Companies Inc., Ulta Salon Cosmetics & Fragrance Inc
# Cluster 58: TransDigm Group
# Cluster 59: Allstate Corp, Chubb Limited, Cincinnati Financial, Progressive Corp., The Travelers Companies Inc., XL Capital
# Cluster 60: Time Warner Inc., Twenty-First Century Fox Class A, Twenty-First Century Fox Class B, The Walt Disney Company
# Cluster 61: C. H. Robinson Worldwide, Expeditors International, FedEx Corporation, J. B. Hunt Transport Services, United Parcel Service
# Cluster 62: DaVita, HCA Holdings, Universal Health Services, Inc.
# Cluster 63: Hanesbrands Inc, Nike, PVH Corp., Under Armour, V.F. Corp.
# Cluster 64: Andeavor, Marathon Petroleum, Phillips 66, Valero Energy
# Cluster 65: AT&T Inc, CenturyLink Inc, Verizon Communications
# Cluster 66: Alexandria Real Estate Equities Inc, Boston Properties, SL Green Realty, Vornado Realty Trust
# Cluster 67: Costco Wholesale Corp., Target Corp., Wal-Mart Stores
# Cluster 68: Eversource Energy, Tapestry, Inc., Walgreens Boots Alliance
# Cluster 69: HCP Inc., Welltower Inc.
# Cluster 70: Alliant Energy Corp, Ameren Corp, American Electric Power, CenterPoint Energy, CMS Energy, Consolidated Edison, Dominion Energy, DTE Energy, Duke Energy, Edison Int'l, Exelon Corp., Hasbro Inc., Mattel Inc., NextEra Energy, NiSource Inc., PG&E Corp., Pinnacle West Capital, PPL Corp., Public Serv. Enterprise Inc., SCANA Corp, Sempra Energy, Southern Co., Wec Energy Group Inc, Xcel Energy Inc

# %%
plotting_df = pd.concat([variation_df[['Name', 'Symbol', 'Sector', 'Color']].reset_index(drop=True),
                         pd.DataFrame(np.stack(embedding, axis=1).T, columns=['x', 'y'])], axis=1)

source = ColumnDataSource(dict(x = plotting_df['x'],
                               y = plotting_df['y'],
                               color = plotting_df['Color'],
                               label = plotting_df['Name'],
                               ticker = plotting_df['Symbol'],
                               sector = plotting_df['Sector']))

hover = HoverTool(tooltips=[
    ("index", "$index"),
    ("name", "@label"),
    ("sector", "@sector"),
    ("ticker", "@ticker"),
    ("(x,y)", "($x, $y)"),
])

p = figure(tools=[TOOLS, hover], plot_width=800, plot_height=700)

labels = LabelSet(x='x', y='y', text='label', source=source, text_font_size='8pt')

p.scatter(x='x', y='y', color='color', legend='sector', source=source)

p.title.text = "2D Company Similarity Visualization (Correlation)"
p.title.text_font_size = "25px"

p.segment(*np.reshape(np.array(segments).flatten(), (len(segments),4)).T) # Comment this line to remove segments

#p.add_layout(labels)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="263a6d22-80dd-4e85-adb6-afd434a016be"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("263a6d22-80dd-4e85-adb6-afd434a016be");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("263a6d22-80dd-4e85-adb6-afd434a016be");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '263a6d22-80dd-4e85-adb6-afd434a016be' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"960585ee-eab3-4b35-b53c-94eee213aceb":{"roots":{"references":[{"attributes":{"below":[{"id":"023e0853-5b57-4d79-a598-b2a685488378","type":"LinearAxis"}],"left":[{"id":"63d3d9f3-e42a-4edd-82a9-6491c1a55c11","type":"LinearAxis"}],"plot_height":700,"plot_width":800,"renderers":[{"id":"023e0853-5b57-4d79-a598-b2a685488378","type":"LinearAxis"},{"id":"abe2ff77-d6c0-4d16-b104-08f80bd6e7b1","type":"Grid"},{"id":"63d3d9f3-e42a-4edd-82a9-6491c1a55c11","type":"LinearAxis"},{"id":"da6c8506-57a7-4ed3-8b7e-561499af2313","type":"Grid"},{"id":"290747f1-9bf8-4b92-a07e-7af571afa264","type":"BoxAnnotation"},{"id":"831326ca-4112-4bb3-bee8-436234bbeff1","type":"Legend"},{"id":"9f967f22-a9dc-42a6-a0f5-b256691b93f9","type":"GlyphRenderer"},{"id":"80782c8a-850f-45e7-af27-3c8975be245f","type":"GlyphRenderer"}],"title":{"id":"49c50e6c-b185-4134-be80-f3c29a132ad5","type":"Title"},"tool_events":{"id":"aedb389d-1973-4bb8-9e2e-9551a923ce05","type":"ToolEvents"},"toolbar":{"id":"02732052-7158-4927-b8ce-2e4eafba9f40","type":"Toolbar"},"x_range":{"id":"78dc5d17-5c73-452a-8e4f-830c52b5dfc4","type":"DataRange1d"},"y_range":{"id":"85466bf8-a47d-4cb4-9dbb-12d80684b9a7","type":"DataRange1d"}},"id":"c185fb61-e425-4dc9-a3fc-1a206febf19f","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"85466bf8-a47d-4cb4-9dbb-12d80684b9a7","type":"DataRange1d"},{"attributes":{"formatter":{"id":"b895fe1f-3edf-44ab-ad8b-925ddd63e55d","type":"BasicTickFormatter"},"plot":{"id":"c185fb61-e425-4dc9-a3fc-1a206febf19f","subtype":"Figure","type":"Plot"},"ticker":{"id":"def34ae9-ea32-4fcc-9a96-37b4a4e76596","type":"BasicTicker"}},"id":"023e0853-5b57-4d79-a598-b2a685488378","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"c185fb61-e425-4dc9-a3fc-1a206febf19f","subtype":"Figure","type":"Plot"},"ticker":{"id":"db0006c6-87c1-4ab5-932a-58a587764ec6","type":"BasicTicker"}},"id":"da6c8506-57a7-4ed3-8b7e-561499af2313","type":"Grid"},{"attributes":{"label":{"field":"sector"},"renderers":[{"id":"9f967f22-a9dc-42a6-a0f5-b256691b93f9","type":"GlyphRenderer"}]},"id":"68698164-1468-44ee-b9ba-409416c4108b","type":"LegendItem"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d5e38cd1-0cbb-496a-baeb-844244ddb76a","type":"HoverTool"},{"id":"1a546152-7876-4c03-b3e1-bc474723b46d","type":"CrosshairTool"},{"id":"6fdee21a-2812-41cb-be13-2383bfe19674","type":"PanTool"},{"id":"c1842889-54c9-4538-adae-f734024c0863","type":"WheelZoomTool"},{"id":"0c5ef5c0-1a8f-4fad-ab47-9e7ef093af02","type":"ResetTool"},{"id":"64fc94f4-fd75-4120-b4b8-22d92ac65098","type":"TapTool"},{"id":"0fc1e1db-4451-4103-8603-e5f1989f993d","type":"SaveTool"},{"id":"593214b7-8d9d-49db-b5b5-c4368e92a34e","type":"BoxSelectTool"}]},"id":"02732052-7158-4927-b8ce-2e4eafba9f40","type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x0":{"field":"x0"},"x1":{"field":"x1"},"y0":{"field":"y0"},"y1":{"field":"y1"}},"id":"72fb0a50-6f83-4dac-ba69-a51f625b47e2","type":"Segment"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"21b5aca7-26c9-4153-94ee-d62220937a3a","type":"Circle"},{"attributes":{"data_source":{"id":"1335db8a-cf6f-4f46-8983-2f6e8eb454b9","type":"ColumnDataSource"},"glyph":{"id":"f74f7fc6-f5c3-478f-abe2-a9db5ea6b19f","type":"Segment"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"72fb0a50-6f83-4dac-ba69-a51f625b47e2","type":"Segment"},"selection_glyph":null},"id":"80782c8a-850f-45e7-af27-3c8975be245f","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","color","label","ticker","sector"],"data":{"color":["#440154","#482374","#482374","#404387","#404387","#440154","#404387","#345E8D","#482374","#29788E","#29788E","#482374","#208F8C","#404387","#440154","#208F8C","#22A784","#482374","#482374","#404387","#42BE71","#29788E","#404 ...

# %% [markdown]
# Note: Segments represent partial correlation coefficients whose absolute value exceed 6%.
#
# Here, companies are much more clearly clustered by industry groups. For example, one can see that airline companies (American Airlines Group, Delta Air Lines, etc) are clustered together and connected to each other.

# %% [markdown]
# # Valuation

# %% [markdown]
# ### NLP Approach

# %%
sim_mat = similarity_matrix_NLP - np.eye(len(similarity_matrix_NLP)) # Subtract identity matrix


def valuation_calculator(index, data, multiple, similarity_matrix):
    sorted_similarity_array = -np.sort((-similarity_matrix[0]))
    sorted_similarity_indices = (-similarity_matrix[index]).argsort()
    top_3_comps = sorted_similarity_array[:3]
    baseline_comp = sorted_similarity_array[4]
    normalized_weights = (top_3_comps - baseline_comp) / sum(top_3_comps - baseline_comp)
    top_3_pe = data[multiple][sorted_similarity_indices[:3]]
    weigthed_pe = np.dot(normalized_weights, top_3_pe)
    if multiple == 'Trailing P/E':
        valuation = weigthed_pe * data['Diluted EPS'][index]
    elif multiple == 'Enterprise Value/EBITDA':
        valuation = weigthed_pe * data['EBITDA'][index]
    elif multiple == 'Enterprise Value/Revenue':
        valuation = weigthed_pe * data['Revenue'][index]
    return valuation


valuation_df_nlp = data[['Name', 'Symbol', 'Sector', 'Color', 'Current Price', 'Enterprise Value']].copy()

for i, company in enumerate(data['Name']):
    valuation_df_nlp.loc[i, 'Valuation (P/E)'] = valuation_calculator(i, data, 'Trailing P/E',
                                                                      sim_mat)
    valuation_df_nlp.loc[i, 'Valuation (EV/EBITDA)'] = valuation_calculator(i, data, 'Enterprise Value/EBITDA',
                                                                            sim_mat)
    valuation_df_nlp.loc[i, 'Valuation (EV/Revenue)'] = valuation_calculator(i, data, 'Enterprise Value/Revenue',
                                                                             sim_mat)

valuation_df_nlp['% Over/Undervaluation (EV/Revenue)'] = (valuation_df_nlp['Valuation (EV/Revenue)'] / \
                                                          valuation_df_nlp['Enterprise Value'] - 1) * 100
valuation_df_nlp['% Over/Undervaluation (EV/EBITDA)'] = (valuation_df_nlp['Valuation (EV/EBITDA)'] / \
                                                         valuation_df_nlp['Enterprise Value'] - 1) * 100  
valuation_df_nlp['% Over/Undervaluation (P/E)'] = (valuation_df_nlp['Valuation (P/E)'] / \
                                                   valuation_df_nlp['Current Price'] - 1) * 100

# %%
valuation_df_nlp['% Over/Undervaluation (EV/Revenue)'].describe()
# Out:
# count     411.000000
# mean      103.566163
# std       460.337165
# min       -91.550410
# 25%       -25.720113
# 50%        13.815492
# 75%        96.308836
# max      8056.229893
# Name: % Over/Undervaluation (EV/Revenue), dtype: float64

# %%
valuation_df_nlp['% Over/Undervaluation (EV/EBITDA)'].describe()
# Out:
# count     411.000000
# mean       31.755578
# std       274.629668
# min       -93.340846
# 25%       -18.816973
# 50%         5.754277
# 75%        38.637978
# max      5460.291038
# Name: % Over/Undervaluation (EV/EBITDA), dtype: float64

# %%
valuation_df_nlp['% Over/Undervaluation (P/E)'].describe()
# Out:
# count     411.000000
# mean       65.848762
# std       244.838387
# min       -97.563081
# 25%       -22.586841
# 50%        11.574105
# 75%        63.616459
# max      2757.431040
# Name: % Over/Undervaluation (P/E), dtype: float64

# %%
# Add the price on the last day of 2016 to the dataframe
last_day_2016 = close_price.loc['2016-12-30', :].rename('2016-12-30 Price')
valuation_df_nlp = valuation_df_nlp.join(last_day_2016, on='Symbol')

# %%
# Calculates the percentage of correct predictions year to date
valuation_df_nlp['Actual Change'] = valuation_df_nlp['Current Price'] > valuation_df_nlp['2016-12-30 Price']
valuation_df_nlp['Prediction'] = valuation_df_nlp['Valuation (P/E)'] > valuation_df_nlp['2016-12-30 Price']
outcome = (valuation_df_nlp['Prediction'] == valuation_df_nlp['Actual Change'])
correct_pred = sum(outcome) / len(outcome)
print('Percentage of correct predictions YTD (NLP): ' + str(correct_pred))
# Out:
# Percentage of correct predictions YTD (NLP): 0.630170316302

# %% [markdown]
# While the system appears to produce valuable predictions, there are many reasons other than luck for which this should not be taken at face value. First, we use the last price of 2016 as a reference, but the financial statements are published later even though they reflect the state of the company at the end of the year. Additionally, much more tests would actually need to performed to evaluate the quality of these signals which is beyond the aim of this notebook.

# %%
source = ColumnDataSource(dict(x = valuation_df_nlp['% Over/Undervaluation (P/E)'],
                               y = valuation_df_nlp['% Over/Undervaluation (EV/EBITDA)'],
                               color = valuation_df_nlp['Color'],
                               label = valuation_df_nlp['Name'],
                               ticker = valuation_df_nlp['Symbol'],
                               sector = valuation_df_nlp['Sector']))

hover = HoverTool(tooltips=[
    ("index", "$index"),
    ("name", "@label"),
    ("sector", "@sector"),
    ("ticker", "@ticker"),
    ("(x,y)", "($x, $y)"),
])

p = figure(tools=[TOOLS, hover], plot_width=800, plot_height=700)

labels = LabelSet(x='x', y='y', text='label', source=source, text_font_size='8pt')

p.scatter(x='x', y='y', color='color', legend='sector', source=source) # Remove "legend='sector'," to remove legend

p.title.text = "Over/Undervaluation (NLP) Based On..."
p.title.text_font_size = "25px"

#p.add_layout(labels) # Comment this line to remove labels

p.xaxis.axis_label = 'Trailing P/E'
p.yaxis.axis_label = 'EV/EBITDA'

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0aae8605-a8ab-43a5-82cf-8afecef59022"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0aae8605-a8ab-43a5-82cf-8afecef59022");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0aae8605-a8ab-43a5-82cf-8afecef59022");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0aae8605-a8ab-43a5-82cf-8afecef59022' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3d87da2d-a2ba-4468-8449-14d8385c82fe":{"roots":{"references":[{"attributes":{},"id":"5a68bb4e-b54a-477e-adb9-cecd39c35f62","type":"BasicTickFormatter"},{"attributes":{},"id":"bb18d113-9372-490b-b467-ca3c01f9beb8","type":"ToolEvents"},{"attributes":{"below":[{"id":"9e453e7d-f2bd-44f2-8d5c-75e252410e08","type":"LinearAxis"}],"left":[{"id":"32c394d3-3bf3-4e97-8d3e-450156f300f8","type":"LinearAxis"}],"plot_height":700,"plot_width":800,"renderers":[{"id":"9e453e7d-f2bd-44f2-8d5c-75e252410e08","type":"LinearAxis"},{"id":"2131c45b-574f-40dd-89b1-2cc1312af33a","type":"Grid"},{"id":"32c394d3-3bf3-4e97-8d3e-450156f300f8","type":"LinearAxis"},{"id":"3fdf7a99-6eb7-4908-9c6b-980af92718cb","type":"Grid"},{"id":"5996ef60-d2d1-4fc4-9890-004864f0a45e","type":"BoxAnnotation"},{"id":"278a1e56-9103-426f-a89a-89298de26850","type":"Legend"},{"id":"9e3d361f-d078-4f88-bca8-494cda791025","type":"GlyphRenderer"}],"title":{"id":"74135ba7-d70e-45ea-acdd-110643f3aea4","type":"Title"},"tool_events":{"id":"bb18d113-9372-490b-b467-ca3c01f9beb8","type":"ToolEvents"},"toolbar":{"id":"3c78168d-5851-4388-b99d-e406ab64ec19","type":"Toolbar"},"x_range":{"id":"8312b73b-1291-4df8-a088-a814770fce88","type":"DataRange1d"},"y_range":{"id":"9bff658b-4086-4e93-bd79-dae63ba7f1c0","type":"DataRange1d"}},"id":"7d558cc6-1d7b-4ed7-a685-32c3d765b262","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5996ef60-d2d1-4fc4-9890-004864f0a45e","type":"BoxAnnotation"},{"attributes":{"label":{"field":"sector"},"renderers":[{"id":"9e3d361f-d078-4f88-bca8-494cda791025","type":"GlyphRenderer"}]},"id":"485a5fd1-116f-497d-b016-df8a674ca0c4","type":"LegendItem"},{"attributes":{"callback":null},"id":"9bff658b-4086-4e93-bd79-dae63ba7f1c0","type":"DataRange1d"},{"attributes":{"callback":null,"overlay":{"id":"5996ef60-d2d1-4fc4-9890-004864f0a45e","type":"BoxAnnotation"},"plot":{"id":"7d558cc6-1d7b-4ed7-a685-32c3d765b262","subtype":"Figure","type":"Plot"},"renderers":[{"id":"9e3d361f-d078-4f88-bca8-494cda791025","type":"GlyphRenderer"}]},"id":"79d4a3ca-8d27-4386-9898-b283bf5f8e71","type":"BoxSelectTool"},{"attributes":{},"id":"323c6734-f2d7-4ce7-9817-5b8d6ab0bb5a","type":"BasicTicker"},{"attributes":{"items":[{"id":"485a5fd1-116f-497d-b016-df8a674ca0c4","type":"LegendItem"}],"plot":{"id":"7d558cc6-1d7b-4ed7-a685-32c3d765b262","subtype":"Figure","type":"Plot"}},"id":"278a1e56-9103-426f-a89a-89298de26850","type":"Legend"},{"attributes":{},"id":"520ad3ca-d7c4-480f-8865-b1a3f84a8e94","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f401f1a7-a539-4f75-861e-61fdc1d8b25c","type":"HoverTool"},{"id":"fc6471d2-cea9-4a91-81c7-407feb9dc426","type":"CrosshairTool"},{"id":"3e3c7514-b77a-4973-854d-0a35549b0178","type":"PanTool"},{"id":"f0a20027-72af-4e1c-b569-a30c13c0d782","type":"WheelZoomTool"},{"id":"8b4d945b-4fcf-42e3-92a5-443ef34101e6","type":"ResetTool"},{"id":"c673abda-5151-4f6b-abd9-d47c3840354c","type":"TapTool"},{"id":"a665f491-ef03-46ac-9933-58d70cc042ee","type":"SaveTool"},{"id":"79d4a3ca-8d27-4386-9898-b283bf5f8e71","type":"BoxSelectTool"}]},"id":"3c78168d-5851-4388-b99d-e406ab64ec19","type":"Toolbar"},{"attributes":{"callback":null,"plot":{"id":"7d558cc6-1d7b-4ed7-a685-32c3d765b262","subtype":"Figure","type":"Plot"}},"id":"c673abda-5151-4f6b-abd9-d47c3840354c","type":"TapTool"},{"attributes":{"plot":{"id":"7d558cc6-1d7b-4ed7-a685-32c3d765b262","subtype":"Figure","type":"Plot"}},"id":"fc6471d2-cea9-4a91-81c7-407feb9dc426","type":"CrosshairTool"},{"attributes":{"plot":null,"text":"Over/Undervaluation (NLP) Based On...","text_font_size":{"value":"25px"}},"id":"74135ba7-d70e-45ea-acdd-110643f3ae ...

# %% [markdown]
# A positive value means that the company should be trading at a higher value (as of the end of 2016). Overall, there appears to be a positive relationship between the valuation based on those two multiples. One caveat, however, is the limited amount of companies. Some companies in the S&P500 have no good comparable companies, and therefore, the percentage of over/undervaluation suggested by the model should not be taken at face value. For example, companies such as Netflix and Amazon appear highly overvalued based on this model. However, this is because idiosyncratic factors have a large influence on these companies which are not captured by this methodology. In fact, on an EV/Revenue basis, the model actually suggests that Amazon is undervalued. Conducting this analysis with a much larger dataset would partially alleviate this issue. An interesting observation is that Nvidia, which has performed very well recently due to developments in the GPU space is still not as "overvalued" as Netflix on the basis of those two multiples.

# %% [markdown]
# ### Correlation Approach

# %%
cols_to_be_used = ['Name', 'Symbol', 'Sector', 'Color', 'Current Price', 'Enterprise Value', 'Trailing P/E',
                   'Enterprise Value/EBITDA', 'Enterprise Value/Revenue']
valuation_df_corr = data[cols_to_be_used].join(variation_df[['Name', 'Cluster']].set_index('Name'), on='Name')
valuation_df_corr = valuation_df_corr.dropna()

valuation_df_corr['Cluster P/E'] = np.nan
valuation_df_corr['Cluster EV/EBITDA'] = np.nan
valuation_df_corr['Cluster EV/Revenue'] = np.nan

for i in range(n_labels + 2):
    valuation_df_corr.loc[valuation_df_corr['Cluster'] == i, 'Cluster P/E'] = \
     np.mean(valuation_df_corr[valuation_df_corr['Cluster'] == i]['Trailing P/E'])
    valuation_df_corr.loc[valuation_df_corr['Cluster'] == i, 'Cluster EV/EBITDA'] = \
     np.mean(valuation_df_corr[valuation_df_corr['Cluster'] == i]['Enterprise Value/EBITDA'])
    valuation_df_corr.loc[valuation_df_corr['Cluster'] == i, 'Cluster EV/Revenue'] = \
     np.mean(valuation_df_corr[valuation_df_corr['Cluster'] == i]['Enterprise Value/Revenue'])

valuation_df_corr['% Over/Undervaluation (EV/Revenue)'] = (valuation_df_corr['Enterprise Value/Revenue'] / \
                                                           valuation_df_corr['Cluster EV/Revenue'] - 1) * 100
valuation_df_corr['% Over/Undervaluation (EV/EBITDA)'] = (valuation_df_corr['Enterprise Value/EBITDA'] / \
                                                          valuation_df_corr['Cluster EV/EBITDA'] - 1) * 100 
valuation_df_corr['% Over/Undervaluation (P/E)'] = (valuation_df_corr['Trailing P/E'] / \
                                                    valuation_df_corr['Cluster P/E'] - 1) * 100

# %%
valuation_df_corr['% Over/Undervaluation (EV/Revenue)'].round(3).describe()
# Out:
# count    379.000000
# mean       0.000016
# std       42.598162
# min      -97.539000
# 25%      -26.306500
# 50%       -3.856000
# 75%       15.045000
# max      205.193000
# Name: % Over/Undervaluation (EV/Revenue), dtype: float64

# %%
valuation_df_corr['% Over/Undervaluation (EV/EBITDA)'].round(3).describe()
# Out:
# count    379.000000
# mean      -0.000008
# std       44.808810
# min      -98.183000
# 25%      -18.822000
# 50%       -2.722000
# 75%       11.299000
# max      639.395000
# Name: % Over/Undervaluation (EV/EBITDA), dtype: float64

# %%
valuation_df_corr['% Over/Undervaluation (P/E)'].round(3).describe()
# Out:
# count     379.000000
# mean        0.000008
# std       103.132365
# min       -92.375000
# 25%       -42.943500
# 50%       -11.989000
# 75%         9.494500
# max      1202.920000
# Name: % Over/Undervaluation (P/E), dtype: float64

# %%
source = ColumnDataSource(dict(x = valuation_df_corr['% Over/Undervaluation (P/E)'],
                               y = valuation_df_corr['% Over/Undervaluation (EV/EBITDA)'],
                               color = valuation_df_corr['Color'],
                               label = valuation_df_corr['Name'],
                               ticker = valuation_df_corr['Symbol'],
                               sector = valuation_df_corr['Sector']))

hover = HoverTool(tooltips=[
    ("index", "$index"),
    ("name", "@label"),
    ("sector", "@sector"),
    ("ticker", "@ticker"),
    ("(x,y)", "($x, $y)"),
])

p = figure(tools=[TOOLS, hover], plot_width=800, plot_height=700)

labels = LabelSet(x='x', y='y', text='label', source=source, text_font_size='8pt')

p.scatter(x='x', y='y', color='color', legend='sector', source=source) # Remove "legend='sector'," to remove legend

p.title.text = "Over/Undervaluation (Correlation) Based On..."
p.title.text_font_size = "25px"

#p.add_layout(labels) # Comment this line to remove labels

p.xaxis.axis_label = 'Trailing P/E'
p.yaxis.axis_label = 'EV/EBITDA'

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f075bbf9-bff8-4b1c-bb32-3705563379c9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f075bbf9-bff8-4b1c-bb32-3705563379c9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f075bbf9-bff8-4b1c-bb32-3705563379c9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f075bbf9-bff8-4b1c-bb32-3705563379c9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c43bb01f-6f84-42c2-9a63-4ca987bc4d9d":{"roots":{"references":[{"attributes":{"axis_label":"EV/EBITDA","formatter":{"id":"fc97e5cf-6177-4940-921c-8911582a6815","type":"BasicTickFormatter"},"plot":{"id":"73f454e9-f6ae-44a1-ae8e-b05358eb6ca3","subtype":"Figure","type":"Plot"},"ticker":{"id":"ea7308ad-ccaf-4b78-b7fb-58a98045d353","type":"BasicTicker"}},"id":"ec5a24e2-3dc9-43b4-a02a-18c85cdd80fe","type":"LinearAxis"},{"attributes":{},"id":"fc97e5cf-6177-4940-921c-8911582a6815","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"73f454e9-f6ae-44a1-ae8e-b05358eb6ca3","subtype":"Figure","type":"Plot"}},"id":"2990478b-2a09-4a83-b70a-9a686cd76b85","type":"ResetTool"},{"attributes":{},"id":"8ffe397a-5334-42cf-81f0-9fc1ebccec5a","type":"BasicTicker"},{"attributes":{"plot":{"id":"73f454e9-f6ae-44a1-ae8e-b05358eb6ca3","subtype":"Figure","type":"Plot"}},"id":"57fee413-3d1d-47a5-aa0e-9a1245688d01","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ae7b7714-2dc3-42a4-a780-029dd6642c6d","type":"Circle"},{"attributes":{"below":[{"id":"51b4f5c1-9e8b-4d17-85bb-f5c64441cc63","type":"LinearAxis"}],"left":[{"id":"ec5a24e2-3dc9-43b4-a02a-18c85cdd80fe","type":"LinearAxis"}],"plot_height":700,"plot_width":800,"renderers":[{"id":"51b4f5c1-9e8b-4d17-85bb-f5c64441cc63","type":"LinearAxis"},{"id":"8212691a-e0ec-4995-9b28-c481ce04837f","type":"Grid"},{"id":"ec5a24e2-3dc9-43b4-a02a-18c85cdd80fe","type":"LinearAxis"},{"id":"800e97e2-7fb9-48d7-a286-5b95dffcced0","type":"Grid"},{"id":"dcf26d0e-08c0-4ded-9d2f-301437b53228","type":"BoxAnnotation"},{"id":"a3ad1570-9776-4523-a1a6-7034a0d8deee","type":"Legend"},{"id":"a690c924-297c-4db4-9c5d-b138dd83b31f","type":"GlyphRenderer"}],"title":{"id":"4ee39b2f-63fb-4347-9d78-c8f8b0a02eee","type":"Title"},"tool_events":{"id":"ef277523-1632-4ae7-9359-8f2670c3c2ac","type":"ToolEvents"},"toolbar":{"id":"d7e905c1-dbd1-417b-997e-9cd972886ec4","type":"Toolbar"},"x_range":{"id":"e007d0b6-0980-4bd9-b591-e7b8e3ec4ca3","type":"DataRange1d"},"y_range":{"id":"470b2194-2fb6-47e6-ae61-7b4617c2fe69","type":"DataRange1d"}},"id":"73f454e9-f6ae-44a1-ae8e-b05358eb6ca3","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"ea7308ad-ccaf-4b78-b7fb-58a98045d353","type":"BasicTicker"},{"attributes":{"callback":null},"id":"470b2194-2fb6-47e6-ae61-7b4617c2fe69","type":"DataRange1d"},{"attributes":{"callback":null,"plot":{"id":"73f454e9-f6ae-44a1-ae8e-b05358eb6ca3","subtype":"Figure","type":"Plot"},"tooltips":[["index","$index"],["name","@label"],["sector","@sector"],["ticker","@ticker"],["(x,y)","($x, $y)"]]},"id":"b3f29655-1477-43f6-a09e-18d85ec8ddff","type":"HoverTool"},{"attributes":{"plot":null,"text":"Over/Undervaluation (Correlation) Based On...","text_font_size":{"value":"25px"}},"id":"4ee39b2f-63fb-4347-9d78-c8f8b0a02eee","type":"Title"},{"attributes":{"fill_color":{"field":"color"},"line_color":{"field":"color"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4a9d9dad-3655-4542-82fe-9a9a86217d2f","type":"Circle"},{"attributes":{"callback":null,"plot":{"id":"73f454e9-f6ae-44a1-ae8e-b05358eb6ca3","subtype":"Figure","type":"Plot"}},"id":"a29b7680-29df-4bd7-960d-5c8687793110","type":"TapTool"},{"attributes":{"plot":{"id":"73f454e9-f6ae-44a1-ae8e-b05358eb6ca3","subtype":"Figure","type":"Plot"}},"id":"d308a218-4416-4be9-9494-d83e15223c18","type":"CrosshairTool"},{"attributes":{},"id":"ef277523-1632-4ae7-9359-8f2670c3c2ac","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b3f29655-1477-43f6-a09e-18d85ec8ddff","type":"HoverTool"},{"id":"d308a218-4416-4be9-9494-d83e15223c18","type":"CrosshairTool"},{"id":"57fee413-3d1d-47a5-aa0e-9a1245688d01","type":"PanTool"},{"id":"09bbb389-8fa2-4b6e-9aa8-5cb067ea36ef","type":"WheelZoomTool"},{"id":"2990478b-2a09-4a83-b70a-9a686cd76b85","type":"ResetTool"},{"id":"a29b7680-2 ...

# %% [markdown]
# This methodology gives valuations which are much less extreme than the NLP approach. One potential explanation for this is that clusters are closer to the traditional industry groups, and therefore, to how the market values companies.

# %% [markdown]
# ### References
#
# Titman, Sheridan and Martin, John D. _Valuation: the Art and Science of Corporate Investment Decisions_. Prentice Hall, 2015. Print.
#
# Quoc Le and Tomas Mikolov. _Distributed Representations of Sentences and Documents_. http://arxiv.org/pdf/1405.4053v2.pdf
#
# Laurens van der Maaten and Geoffrey Hinton. _Visualizing Data using t-SNE_. http://www.jmlr.org/papers/volume9/vandermaaten08a/vandermaaten08a.pdf
#
# Gael Varoquaux. _Visualizing the Stock Market Structure_. http://scikit-learn.org/stable/auto_examples/applications/plot_stock_market.html#sphx-glr-auto-examples-applications-plot-stock-market-py
