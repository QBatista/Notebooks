# %% [markdown]
# # Data Scraping

# %% [markdown]
# I fetch the data for NBER Working paper abstracts through the program archive (http://www.nber.org/papersbyprog/). Each program archive contains two links: one for recent papers and one for older papers. Working paper abstracts are also available at http://nber.org/new_archive/. However, it seems that this webpage doesn't work properly; the links for papers before 2013 don't work.

# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen

program_url = 'http://www.nber.org/papersbyprog/'
programs_data = pd.DataFrame(columns=['program', 'main_url', 'archive_url',
                                      'number_of_papers'])

# Fetch content of program's webpage
soup = BeautifulSoup(urlopen(program_url).read(), 'html.parser')
table = soup.findAll('table', {'border': 0, 'cellspacing': 1,
                               'cellpadding': 4})[0]

# Get strings of text
strings = list(table.stripped_strings)
programs_data['program'] = strings[0::2] 
programs_data['number_of_papers'] = \
pd.Series(strings[1::2]).str.extract('(\d+)', expand=False).astype(int)

# Get url for program
for row in table.findAll('a'):
    programs_data.loc[programs_data['program'] == row.text, 'main_url'] = \
    program_url + row['href']
    programs_data.loc[programs_data['program'] == row.text, 'archive_url'] = \
    program_url + row['href'].replace('.', '_archive.')

# %%
programs_data
# Out:
#                                            program  \
# 0                                            Aging
# 1                                    Asset Pricing
# 2                                Corporate Finance
# 3                                         Children
# 4              Development of the American Economy
# 5                            Development Economics
# 6                           Economics of Education
# 7                 Environment and Energy Economics
# 8                 Economic Fluctuations and Growth
# 9                                      Health Care
# 10                                Health Economics
# 11        International Finance and Macroeconomics
# 12                         Industrial Organization
# 13              International Trade and Investment
# 14                               Law and Economics
# 15                                   Labor Studies
# 16                              Monetary Economics
# 17                                Public Economics
# 18                               Political Economy
# 19  Productivity, Innovation, and Entrepreneurship
# 20                        Technical Working Papers
#
#                                      main_url  \
# 0    http://www.nber.org/papersbyprog/AG.html
# 1    http://www.nber.org/papersbyprog/AP.html
# 2    http://www.nber.org/papersbyprog/CF.html
# 3    http://www.nber.org/papersbyprog/CH.html
# 4   http://www.nber.org/papersbyprog/DAE.html
# 5   http://www.nber.org/papersbyprog/DEV.html
# 6    http://www.nber.org/papersbyprog/ED.html
# 7   http://www.nber.org/papersbyprog/EEE.html
# 8   http://www.nber.org/papersbyprog/EFG.html
# 9    http://www.nber.org/papersbyprog/HC.html
# 10   http://www.nber.org/papersbyprog/HE.html
# 11  http://www.nber.org/papersbyprog/IFM.html
# 12   http://www.nber.org/papersbyprog/IO.html
# 13  http://www.nber.org/papersbyprog/ITI.html
# 14   http://www.nber.org/papersbyprog/LE.html
# 15   http://www.nber.org/papersbyprog/LS.html
# 16   http://www.nber.org/papersbyprog/ME.html
# 17   http://www.nber.org/papersbyprog/PE.html
# 18  http://www.nber.org/papersbyprog/POL.html
# 19   http://www.nber.org/papersbyprog/PR.html
# 20  http://www.nber.org/papersbyprog/TWP.html
#
#                                           archive_url  number_of_papers
# 0    http://www.nber.org/papersbyprog/AG_archive.html              1347
# 1    http://www.nber.org/papersbyprog/AP_archive.html              2181
# 2    http://www.nber.org/papersbyprog/CF_archive.html              1785
# 3    http://www.nber.org/papersbyprog/CH_archive.html              1312
# 4   http://www.nber.org/papersbyprog/DAE_archive.html              1432
# 5   http://www.nber.org/papersbyprog/DEV_archive.html               716
# 6    http://www.nber.org/papersbyprog/ED_archive.html              1230
# 7   http://www.nber.org/papersbyprog/EEE_archive.html               924
# 8   http://www.nber.org/papersbyprog/EFG_archive.html              4842
# 9    http://www.nber.org/papersbyprog/HC_archive.html              1292
# 10   http://www.nber.org/papersbyprog/HE_archive.html              1796
# 11  http://www.nber.org/papersbyprog/IFM_archive.html              3702
# 12   http://www.nber.org/papersbyprog/IO_archive.html              1328
# 13  http://www.nber.org/papersbyprog/ITI_archive.html              3160
# 14   http://www.nber.org/papersbyprog/LE_archive.html               901
# 15   http://www.nber.org/papersbyprog/LS_archive.html              4770
# 16   http://www.nber.org/papersbyprog/ME_archive.html              2817
# 17   http://www.nber.org/papersbyprog/PE_archive.html              4787
# 18  http://www.nber.org/papersbyprog/POL_archive.html               924
# 19   http://www.nber.org/papersbyprog/PR_archive.html              1914
# 20  http://www.nber.org/papersbyprog/TWP_archive.html               288

# %%
# Total number of papers (including duplicates)
sum(programs_data.number_of_papers)
# Out:
# 43448

# %%
papers_data = pd.DataFrame(columns=['id', 'title', 'authors', 'program', 'url', 'year', 'abstract'])

for papers_url in programs_data[['main_url', 'archive_url']].values.ravel():
    soup = BeautifulSoup(urlopen(papers_url).read(), 'html.parser')
    table = soup.findAll('table', {'border': 0, 'cellspacing': 1,
                                   'cellpadding': 4})[0]

    for row in table.findAll('a'):
        row_index = len(papers_data)
        papers_data.loc[row_index, 'id'] = row.text
        papers_data.loc[row_index, 'url'] = row['href']

# %%
papers_data = papers_data.drop_duplicates()
papers_data = papers_data[papers_data.url != '']

# Retain only the IDs which start by 'w' or 't' followed by a digit.
# This is used because other IDs do not appear to contain abstracts.
papers_data = papers_data[papers_data.id.str.contains(' [tw][0-9]')].reset_index(drop=True)

# Total number of unique papers
papers_data.shape[0]
# Out:
# 24317

# %%
import re

for i, url in enumerate(papers_data.url):
    soup = BeautifulSoup(urlopen(url).read(), 'html.parser')
    table = soup.findAll('table', {'id': 'mainTable'})[0]
    abstract = soup.findAll('p', {'style': 'margin-left: 40px; margin-right: 40px; text-align: justify'}, text=True)
    
    text = ''
    for paragraph in abstract:
        text += paragraph.text
    papers_data.loc[i, 'abstract'] = text
    
    papers_data.loc[i, 'title'] = table.findAll('h1', {'class': 'title'})[0].text
    papers_data.loc[i, 'authors'] = table.findAll('h2', {'class': 'bibtop'})[0].text
    temp_str = table.findAll('p', {'class': 'bibtop'})[0].text
    papers_data.loc[i, 'program'] = re.search(':(.*)', temp_str).group(1)
    papers_data.loc[i, 'year'] = re.search('Issued in (.*)', temp_str).group(1)

# %% [markdown]
# # String Matching Analysis

# %% [markdown]
# I considered two approaches here. The first was to use an approximate string matching technique such as [Levenhstein distance](https://en.wikipedia.org/wiki/Levenshtein_distance) to realize the matches using the original keywords in the article's chart. The problem is that this technique is not sufficiently powerful for this application.This is particularly evident for the string 'dynamic stochastic general equilibrium' which is closer to 'equilibrium' than to 'dsge'. As such, using this technique would give meaningless results for this string. Additionally, even though strings such as 'neural nets' and 'machine learning' are closely related from a semantical point of view, they are far away from each other based on Levenhstein distance. As such, I resorted to using a dictionary containing different variants of the original keywords to match the strings.

# %%
papers_data = pd.read_csv('nber_abstracts.csv', index_col=0)

# %%
papers_data['abstract'] = papers_data['abstract'].str.lower()
papers_data['title'] = papers_data['title'].str.lower()

# %%
techniques = {'diff-in-diff': ['difference in difference', 'differences in difference',
                                                'difference-in-difference', 'differences-in-difference',
                                                'diff-in-diff', 'diff in diff'],
                         'regression discontinuity': ['regression discontinuity'],
                         'dynamic stochastic general equilibrium': ['dynamic stochastic general equilibrium', 'dsge',
                                                                                                'dynamic general equilibrium', 'sdge', 'dge'],
                         'randomized controlled trial': ['randomized controlled trial', 'rct'],
                         'laboratory experiments': ['laboratory', 'lab experiment'],
                         'machine learning': ['machine learning', 'big data', 'deep learning',
                                                           'supervised learning', 'unsupervised learning',
                                                           'reinforcement learning', 'neural nets', 'semi-supervised learning'],
                        'artificial intelligence': [ 'artificial intelligence']
                         }

# %%
for technique in techniques.keys():
    papers_data[technique] = 0
    for key in techniques[technique]:
        papers_data[technique] += papers_data['abstract'].str.contains(key)
        papers_data[technique] += papers_data['title'].str.contains(key)
    papers_data[technique] = papers_data[technique] > 0

# %%
papers_data['year'] = papers_data['year'].str.split(',').str[0].str.extract('(\d+)').astype(np.int)
# Out:
# /Users/QBatista/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %%
grouped = papers_data.groupby('year')
summary_stats = grouped.sum()
summary_stats = summary_stats.divide(grouped.size(), axis='rows')*100

# %%
moving_average = summary_stats.rolling(window=5,center=False).mean()

# %%
lines = []
legend_it = []

colors = all_palettes['Category10'][len(moving_average.columns)]

p = figure(tools=TOOLS, plot_width=800,
                  plot_height=600, toolbar_location="above")

for (i, col) in enumerate(moving_average.columns): 
    temp_line = p.line(x=moving_average.index.values,
                                     y=moving_average[col],
                                     color=colors[i])
    legend_it.append((col, [temp_line]))
    
legend = Legend(items=legend_it, location=(0, 25))
p.add_layout(legend, 'right')

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="af20b5c6-c22f-4365-b39b-f32c50fd6625">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0bdefd8d-9c94-4a0d-bf71-00fe63e6cc2a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0bdefd8d-9c94-4a0d-bf71-00fe63e6cc2a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0bdefd8d-9c94-4a0d-bf71-00fe63e6cc2a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0bdefd8d-9c94-4a0d-bf71-00fe63e6cc2a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1568b4e2-f06a-4a69-9309-886181384e46":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"d1cc3868-15bd-47ec-942d-4d9713e72bb4","subtype":"Figure","type":"Plot"},"ticker":{"id":"98dd3338-9a1a-4f1e-9385-e8ddb91dfa18","type":"BasicTicker"}},"id":"c2dd988a-bc40-4cde-afd5-7b0093045bb0","type":"Grid"},{"attributes":{"line_color":{"value":"#d62728"},"x":{"field":"x"},"y":{"field":"y"}},"id":"68e29394-3dc0-42ef-a13a-b9cb28b84f05","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1973,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018],"y":{"__ndarray__":"...","dtype":"float64","shape":[45]}}},"id":"aa708906-e4fe-4fdd-9cd3-2fcb095047d5","type":"ColumnDataSource"},{"attributes":{},"id":"8f8f3bc3-726f-4607-8ef2-ea31dff7f089","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#e377c2"},"x":{"field":"x"},"y":{"field":"y"}},"id":"65544aff-c684-45af-abfb-85a6517cd14f","type":"Line"},{"attributes":{"label":{"value":"diff-in-diff"},"renderers":[{"id":"1fd5ac66-0e97-427a-a886-1d6e347afa69","type":"GlyphRenderer"}]},"id":"5a2de683-e22b-4c55-8317-86ffb4e3dd16","type":"LegendItem"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b9ac4d90-fa9f-47fc-a2fa-b59a82357d6a","type":"CrosshairTool"},{"id":"504e5e8a-5af6-4764-9a23-5e6bb0b9ba48","type":"PanTool"},{"id":"640523bd-6d9d-42ef-ac39-13c2087ec569","type":"WheelZoomTool"},{"id":"4e69f2cc-0af3-4866-b58d-3cf55e5a7099","type":"ResetTool"},{"id":"71156c6f-6661-41f9-93a6-ed5027f99d5a","type":"TapTool"},{"id":"346fb947-76ae-47ee-b0bb-d2740a2797c3","type":"SaveTool"}]},"id":"4509ec76-892c-4d24-85fb-5bc31f4a5cde","type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6e96eb03-9788-42da-9813-a13fe34fd5b8","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1973,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018],"y":{"__ndarray__":"...","dtype":"float64","shape":[45]}}},"id":"75c067a2-08bd-4472-9838-ee8a449cc150","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"7806cf0b-2fca-45dc-8eb5-0e8beaa137cb","type":"ColumnDataSource"},"glyph":{"id":"65544aff-c684-45af-abfb-85a6517cd14f","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b28237f2-46a6-4677-a9c0-635014390579","type":"Line"},"selection_glyph":null},"id":"74e3cdfe-a1a8-4486-9be4-92bc37792c6c","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1973,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018],"y":{"__ndarray__":"...","dtype":"float64","shape":[45]}}},"id":"78b0e8d4-b000-4f2c-8e33-16a0fcdc351e","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b28237f2-46a6-4677-a9c0-635014390579","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3d37c356-cf35-47ee-9322-2cf2e3407b62","type":"Line"},{"attributes":{"data_source":{"id":"aa708906-e4fe-4fdd-9cd3-2fcb095047d5","type":"ColumnDataSource"},"glyph":{"id":"f90120e7-3eae-46f0-a9f6-af0a680d2f6e","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2f1b328e-1de6-4857-9086-6bd82945d63a","type":"Line"},"selection_glyph":null},"id":"640a36c7-516a-4429-a259-ad40d8835a2d","type":"Glyph ...

# %% [markdown]
# ## Observations
#
# - The original article seems to fail to account for variants of the keywords, and as such, underestimates the actual percentages
# - Randomized controlled trials, difference in differences, machine learning and artificial intelligence have spiked in popularity since the original article was published
